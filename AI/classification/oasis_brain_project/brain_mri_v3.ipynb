# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.svm import LinearSVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Reading

# %%
df = pd.read_csv("oasis_longitudinal.csv")

# %% [markdown]
# ### Set random state

# %%
RANDOM_STATE = 13

# %% [markdown]
# ## EDA

# %%
# MR Delay
# after how many days visit based on first visit

# EDUC
# How many years educate

# SES
# Socioeconomic Status
# 5 means LOW and 1 means HIGH?

# MMSE
# Mini‐Mental State Examination

# CDR
# Clinical Dementia Rating

# eTIV
# Estimated total intracranial volume

# nWBV
# Normalize Whole Brain Volume

# ASF
# Atlas Scaling Factor

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df.tail()
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 368    16  1.0  28.0  0.5  1693  0.694  1.037
# 369    16  1.0  26.0  0.5  1688  0.675  1.040
# 370    13  2.0  30.0  0.0  1319  0.801  1.331
# 371    13  2.0  30.0  0.0  1327  0.796  1.323
# 372    13  2.0  30.0  0.0  1333  0.801  1.317

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subject ID  373 non-null    object
#  1   MRI ID      373 non-null    object
#  2   Group       373 non-null    object
#  3   Visit       373 non-null    int64
#  4   MR Delay    373 non-null    int64
#  5   M/F         373 non-null    object
#  6   Hand        373 non-null    object
#  7   Age         373 non-null    int64
#  8   EDUC        373 non-null    int64
#  9   SES         354 non-null    float64
#  10  MMSE        371 non-null    float64
#  11  CDR         373 non-null    float64
#  12  eTIV        373 non-null    int64
#  13  nWBV        373 non-null    float64
#  14  ASF         373 non-null    float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 43.8+ KB

# %%
df.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  373.000000   373.000000  373.000000  373.000000  354.000000
# mean     1.882038   595.104558   77.013405   14.597855    2.460452
# std      0.922843   635.485118    7.640957    2.876339    1.134005
# min      1.000000     0.000000   60.000000    6.000000    1.000000
# 25%      1.000000     0.000000   71.000000   12.000000    2.000000
# 50%      2.000000   552.000000   77.000000   15.000000    2.000000
# 75%      2.000000   873.000000   82.000000   16.000000    3.000000
# max      5.000000  2639.000000   98.000000   23.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  371.000000  373.000000   373.000000  373.000000  373.000000
# mean    27.342318    0.290885  1488.128686    0.729568    1.195461
# std      3.683244    0.374557   176.139286    0.037135    0.138092
# min      4.000000    0.000000  1106.000000    0.644000    0.876000
# 25%     27.000000    0.000000  1357.000000    0.700000    1.099000
# 50%     29.000000    0.000000  1470.000000    0.729000    1.194000
# 75%     30.000000    0.500000  1597.000000    0.756000    1.293000
# max     30.000000    2.000000  2004.000000    0.837000    1.587000

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Handeling SES nan values

# %%
df.SES.hist(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %%
df.SES.mean()
# Out:
# 2.4604519774011298

# %%
df.SES.unique()
# Out:
# array([ 2., nan,  3.,  4.,  1.,  5.])

# %%
df.groupby(["SES"]).mean()
# Out:
#         Visit    MR Delay        Age       EDUC       MMSE       CDR  \
# SES
# 1.0  2.011364  672.181818  77.829545  17.340909  27.602273  0.301136
# 2.0  1.815534  562.961165  76.679612  15.446602  28.067961  0.179612
# 3.0  1.865854  555.634146  77.243902  13.987805  27.573171  0.280488
# 4.0  1.864865  632.851351  76.243243  11.959459  26.378378  0.337838
# 5.0  1.714286  478.428571  78.142857   8.000000  24.285714  0.428571
#
#             eTIV      nWBV       ASF
# SES
# 1.0  1571.204545  0.716614  1.131739
# 2.0  1489.339806  0.735223  1.195087
# 3.0  1442.573171  0.741890  1.229829
# 4.0  1460.202703  0.725595  1.214378
# 5.0  1349.000000  0.722571  1.314429

# %%
# fill nan values function for SES
def fill_ses(x):
    ses = 0
    if x > 17:
        ses = 1.0
    elif (x < 17) and (x > 15):
        ses = 2.0
    elif (x < 15) and (x > 13):
        ses = 3.0
    elif (x < 13) and (x > 11):
        ses = 4.0
    else:
        ses = 5.0
    return ses

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df["SES"] = df.apply(lambda x : fill_ses(x.EDUC) if pd.isna(x.SES)   else x.SES, axis = 1)

# %%
# convert float to int to use less memory
df["SES"] = df.SES.astype(int)

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    2  27.0  0.0  1987  0.696  0.883
# 1    2  30.0  0.0  2004  0.681  0.876
# 2    4  23.0  0.5  1678  0.736  1.046
# 3    4  28.0  0.5  1738  0.713  1.010
# 4    4  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# ### Handeling MMSE nan values

# %%
df.MMSE.hist()
# Out:
# <AxesSubplot:>

# %%
df.groupby(["MMSE"]).mean()
# Out:
#          Visit     MR Delay        Age       EDUC       SES       CDR  \
# MMSE
# 4.0   5.000000  1233.000000  69.000000  16.000000  1.000000  1.000000
# 7.0   4.000000   970.000000  68.000000  16.000000  1.000000  1.000000
# 15.0  2.000000   473.500000  73.500000  14.000000  3.500000  1.500000
# 16.0  2.333333   841.000000  73.666667  13.333333  3.666667  1.000000
# 17.0  1.800000   524.000000  70.000000  12.800000  3.200000  0.800000
# 18.0  2.500000  1023.000000  78.500000  10.000000  3.500000  0.750000
# 19.0  1.666667   215.666667  69.000000  14.666667  1.333333  1.000000
# 20.0  1.571429   372.857143  78.428571  13.285714  3.000000  0.714286
# 21.0  1.545455   315.636364  78.181818  14.181818  3.000000  0.909091
# 22.0  2.000000   646.285714  75.571429  13.142857  3.285714  0.714286
# 23.0  1.363636   247.090909  78.727273  11.727273  3.363636  0.636364
# 24.0  1.750000   516.000000  80.000000  14.500000  2.250000  0.500000
# 25.0  1.500000   380.333333  76.666667  14.250000  2.416667  0.625000
# 26.0  1.750000   633.150000  79.300000  14.850000  2.900000  0.500000
# 27.0  1.968750   529.843750  79.093750  13.187500  2.843750  0.453125
# 28.0  1.866667   597.933333  77.222222  14.533333  2.466667  0.222222
# 29.0  1.846154   612.197802  77.593407  15.219780  2.395604  0.109890
# 30.0  1.982456   676.798246  75.947368  15.228070  2.245614  0.078947
#
#              eTIV      nWBV       ASF
# MMSE
# 4.0   1701.000000  0.676000  1.032000
# 7.0   1714.000000  0.682000  1.024000
# 15.0  1366.000000  0.689000  1.285500
# 16.0  1520.000000  0.705667  1.156000
# 17.0  1569.000000  0.701400  1.122600
# 18.0  1471.500000  0.669500  1.193000
# 19.0  1560.333333  0.710000  1.146000
# 20.0  1555.000000  0.700429  1.138000
# 21.0  1439.000000  0.683727  1.232091
# 22.0  1456.857143  0.713286  1.221286
# 23.0  1545.636364  0.714727  1.141273
# 24.0  1355.000000  0.720750  1.299250
# 25.0  1481.916667  0.727167  1.210000
# 26.0  1472.650000  0.718150  1.210000
# 27.0  1449.281250  0.729656  1.224156
# 28.0  1497.088889  0.737422  1.188222
# 29.0  1476.747253  0.734220  1.205967
# 30.0  1507.614035  0.738833  1.179246

# %%
df["MMSE"].mean()
# Out:
# 27.342318059299192

# %%
df["MMSE"].median()
# Out:
# 29.0

# %%
df[df["MMSE"].isna()]
# Out:
#     Subject ID         MRI ID     Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 357  OAS2_0181  OAS2_0181_MR2  Demented      2       539   F    R   75    12
# 358  OAS2_0181  OAS2_0181_MR3  Demented      3      1107   F    R   77    12
#
#      SES  MMSE  CDR  eTIV   nWBV    ASF
# 357    4   NaN  1.0  1169  0.742  1.501
# 358    4   NaN  1.0  1159  0.733  1.515

# %%
df[df["Group"] == "Demented"]["MMSE"].median()
# Out:
# 26.0

# %%
df[df["MMSE"] < 26]["Group"].unique()
# Out:
# array(['Demented', 'Converted'], dtype=object)

# %%
df["MMSE"] = df.MMSE.fillna(df[df["Group"] == "Demented"]["MMSE"].median())

# %% [markdown]
# ### Replace M/F values

# %%
df["M/F"] = np.where(df["M/F"] == "M", 1, 0)

# %% [markdown]
# ### Drop Hand & MRI ID

# %%
df.drop(["Hand", "MRI ID"], axis = 1, inplace = True)

# %% [markdown]
# ### Replace Group values
#
# Example of how **Converted** Group should be handeled:
#
# - before:
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 1
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 2
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 3
#
# - after:
#
#     - Subject ID = OAS2_0020,Group = Nondemented, Visit = 1
#
#     - Subject ID = OAS2_0020,Group = Nondemented, Visit = 2
#
#     - Subject ID = OAS2_0020,Group = Demented, Visit = 3

# %%
df.iloc[30:40]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 30  OAS2_0017  Nondemented      3       617    1   81    12    3  27.0  0.5
# 31  OAS2_0017  Nondemented      4      1861    1   85    12    3  30.0  0.0
# 32  OAS2_0017  Nondemented      5      2400    1   86    12    3  27.0  0.0
# 33  OAS2_0018    Converted      1         0    0   87    14    1  30.0  0.0
# 34  OAS2_0018    Converted      3       489    0   88    14    1  29.0  0.0
# 35  OAS2_0018    Converted      4      1933    0   92    14    1  27.0  0.5
# 36  OAS2_0020    Converted      1         0    1   80    20    1  29.0  0.0
# 37  OAS2_0020    Converted      2       756    1   82    20    1  28.0  0.5
# 38  OAS2_0020    Converted      3      1563    1   84    20    1  26.0  0.5
# 39  OAS2_0021     Demented      1         0    1   72    20    1  26.0  0.5
#
#     eTIV   nWBV    ASF
# 30  1814  0.759  0.968
# 31  1820  0.755  0.964
# 32  1813  0.761  0.968
# 33  1406  0.715  1.248
# 34  1398  0.713  1.255
# 35  1423  0.696  1.234
# 36  1587  0.693  1.106
# 37  1606  0.677  1.093
# 38  1597  0.666  1.099
# 39  1911  0.719  0.919

# %%
max_visit = df[df["Group"] == "Converted"].groupby(["Subject ID"]).max().reset_index()[["Subject ID","Visit"]]
for i in range(max_visit.shape[0]):
    target_index =  df[(df["Subject ID"] == max_visit.loc[i,"Subject ID"]) & (df["Visit"] != max_visit.loc[i,"Visit"]) ].index
    df.loc[target_index,"Group"] = "Nondemented"

# %%
df.iloc[30:40]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 30  OAS2_0017  Nondemented      3       617    1   81    12    3  27.0  0.5
# 31  OAS2_0017  Nondemented      4      1861    1   85    12    3  30.0  0.0
# 32  OAS2_0017  Nondemented      5      2400    1   86    12    3  27.0  0.0
# 33  OAS2_0018  Nondemented      1         0    0   87    14    1  30.0  0.0
# 34  OAS2_0018  Nondemented      3       489    0   88    14    1  29.0  0.0
# 35  OAS2_0018    Converted      4      1933    0   92    14    1  27.0  0.5
# 36  OAS2_0020  Nondemented      1         0    1   80    20    1  29.0  0.0
# 37  OAS2_0020  Nondemented      2       756    1   82    20    1  28.0  0.5
# 38  OAS2_0020    Converted      3      1563    1   84    20    1  26.0  0.5
# 39  OAS2_0021     Demented      1         0    1   72    20    1  26.0  0.5
#
#     eTIV   nWBV    ASF
# 30  1814  0.759  0.968
# 31  1820  0.755  0.964
# 32  1813  0.761  0.968
# 33  1406  0.715  1.248
# 34  1398  0.713  1.255
# 35  1423  0.696  1.234
# 36  1587  0.693  1.106
# 37  1606  0.677  1.093
# 38  1597  0.666  1.099
# 39  1911  0.719  0.919

# %%
df["Group"] = np.where(df["Group"] == "Nondemented", 0, 1)

# %%
df.iloc[30:40]
# Out:
#    Subject ID  Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV  \
# 30  OAS2_0017      0      3       617    1   81    12    3  27.0  0.5  1814
# 31  OAS2_0017      0      4      1861    1   85    12    3  30.0  0.0  1820
# 32  OAS2_0017      0      5      2400    1   86    12    3  27.0  0.0  1813
# 33  OAS2_0018      0      1         0    0   87    14    1  30.0  0.0  1406
# 34  OAS2_0018      0      3       489    0   88    14    1  29.0  0.0  1398
# 35  OAS2_0018      1      4      1933    0   92    14    1  27.0  0.5  1423
# 36  OAS2_0020      0      1         0    1   80    20    1  29.0  0.0  1587
# 37  OAS2_0020      0      2       756    1   82    20    1  28.0  0.5  1606
# 38  OAS2_0020      1      3      1563    1   84    20    1  26.0  0.5  1597
# 39  OAS2_0021      1      1         0    1   72    20    1  26.0  0.5  1911
#
#      nWBV    ASF
# 30  0.759  0.968
# 31  0.755  0.964
# 32  0.761  0.968
# 33  0.715  1.248
# 34  0.713  1.255
# 35  0.696  1.234
# 36  0.693  1.106
# 37  0.677  1.093
# 38  0.666  1.099
# 39  0.719  0.919

# %% [markdown]
# ## Processing

# %% [markdown]
# ### A list to remember and compare details

# %%
model_details = []

# %% [markdown]
# ### Split Data

# %%
# GroupShuffleSplit should be used because it is important to model to learn each patient fully (all visit for each patient).
splitter = GroupShuffleSplit(test_size=.20, n_splits=1, random_state = RANDOM_STATE)

# %%
split = splitter.split(df, groups=df['Subject ID'])
train_indexes, test_indexes = next(split)

train = df.iloc[train_indexes]
test = df.iloc[test_indexes]

# %%
X_train = train.drop(["Subject ID", "Group"], axis = 1)
y_train = train[["Group"]]

# %%
X_test = test.drop(["Subject ID", "Group"], axis = 1)
y_test = test[["Group"]]

# %% [markdown]
# ### Normalization

# %%
delay_scaler = MinMaxScaler()
age_scaler = MinMaxScaler()
educ_scaler = MinMaxScaler()
mmse_scaler = MinMaxScaler()
etiv_scaler = MinMaxScaler()

delay_scaler.fit(X_train["MR Delay"].to_numpy().reshape(-1,1))
age_scaler.fit(X_train["Age"].to_numpy().reshape(-1,1))
educ_scaler.fit(X_train["EDUC"].to_numpy().reshape(-1,1))
mmse_scaler.fit(X_train["MMSE"].to_numpy().reshape(-1,1))
etiv_scaler.fit(X_train["eTIV"].to_numpy().reshape(-1,1))

X_train["MR Delay"] = delay_scaler.transform(X_train["MR Delay"].to_numpy().reshape(-1,1))
X_train["Age"] = age_scaler.transform(X_train["Age"].to_numpy().reshape(-1,1))
X_train["EDUC"] = educ_scaler.transform(X_train["EDUC"].to_numpy().reshape(-1,1))
X_train["MMSE"] = mmse_scaler.transform(X_train["MMSE"].to_numpy().reshape(-1,1))
X_train["eTIV"] = etiv_scaler.transform(X_train["eTIV"].to_numpy().reshape(-1,1))

X_test["MR Delay"] = delay_scaler.transform(X_test["MR Delay"].to_numpy().reshape(-1,1))
X_test["Age"] = age_scaler.transform(X_test["Age"].to_numpy().reshape(-1,1))
X_test["EDUC"] = educ_scaler.transform(X_test["EDUC"].to_numpy().reshape(-1,1))
X_test["MMSE"] = mmse_scaler.transform(X_test["MMSE"].to_numpy().reshape(-1,1))
X_test["eTIV"] = etiv_scaler.transform(X_test["eTIV"].to_numpy().reshape(-1,1))

# %% [markdown]
# ### Logestic Regression

# %%
lr = LogisticRegression( max_iter = 1000)
lr.fit(X_train, y_train)
lr_prediction = lr.predict(X_test)
print(classification_report(y_test,lr_prediction, target_names= ["Non-Demanted", "Demanted"]))
lr_conf = confusion_matrix(y_test,lr_prediction)
model_details.append(["LogisticRegression", round(f1_score(y_test,lr_prediction, average = "weighted") * 100,4),lr_conf[1,0]])
lr_plot_conf = ConfusionMatrixDisplay(lr_conf)
lr_plot_conf.plot()
# Out:
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      0.90      0.95        39
#     Demanted       0.89      1.00      0.94        34
#
#     accuracy                           0.95        73
#    macro avg       0.95      0.95      0.95        73
# weighted avg       0.95      0.95      0.95        73
# /home/amyrmahdy/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### RandomForest Classification

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
rfc_prediction = rfc.predict(X_test)
print(classification_report(y_test,rfc_prediction, target_names= ["Non-Demanted", "Demanted"]))
rfc_conf = confusion_matrix(y_test,rfc_prediction)
model_details.append(["RandomForestClassifier", round(f1_score(y_test,rfc_prediction, average = "weighted") * 100,4),rfc_conf[1,0]])
rfc_plot_conf = ConfusionMatrixDisplay(rfc_conf)
rfc_plot_conf.plot()
# Out:
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      0.90      0.95        39
#     Demanted       0.89      1.00      0.94        34
#
#     accuracy                           0.95        73
#    macro avg       0.95      0.95      0.95        73
# weighted avg       0.95      0.95      0.95        73
# /tmp/ipykernel_4793/450862791.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(X_train, y_train)

# %% [markdown]
# ### LinearSVC

# %%
lsvc = LinearSVC(max_iter = 100000)
lsvc.fit(X_train, y_train)
lsvc_prediction = lsvc.predict(X_test)
print(classification_report(y_test,lsvc_prediction, target_names= ["Non-Demanted", "Demanted"]))
lsvc_conf = confusion_matrix(y_test,lsvc_prediction)
model_details.append(["LinearSVC", round(f1_score(y_test,lsvc_prediction, average = "weighted") * 100,4),lsvc_conf[1,0]])
lsvc_plot_conf = ConfusionMatrixDisplay(lsvc_conf)
lsvc_plot_conf.plot()
# Out:
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      0.90      0.95        39
#     Demanted       0.89      1.00      0.94        34
#
#     accuracy                           0.95        73
#    macro avg       0.95      0.95      0.95        73
# weighted avg       0.95      0.95      0.95        73
# /home/amyrmahdy/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Simple Neural Network

# %%
def build_snn():
    snn = tf.keras.Sequential()
    snn.add(tf.keras.layers.InputLayer(X_train.shape[1],))
    snn.add(tf.keras.layers.Dense(100,activation = "relu"))
    snn.add(tf.keras.layers.Dense(50,activation = "relu"))
    snn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    snn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return snn

# %%
snn = build_snn()
snn.fit(X_train, y_train, epochs = 100)
not_final_snn_prediction = snn.predict(X_test)
snn_prediction = np.where(not_final_snn_prediction > 0.5, 1, 0)
print(classification_report(y_test,snn_prediction, target_names= ["Non-Demanted", "Demanted"]))
snn_conf = confusion_matrix(y_test,snn_prediction)
model_details.append(["SNN", round(f1_score(y_test,snn_prediction, average = "weighted") * 100,4),snn_conf[1,0]])
snn_plot_conf = ConfusionMatrixDisplay(snn_conf)
snn_plot_conf.plot()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6435 - accuracy: 0.6600
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7633
# Epoch 3/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5238 - accuracy: 0.8000
# Epoch 4/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4765 - accuracy: 0.8200
# Epoch 5/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4267 - accuracy: 0.8667
# Epoch 6/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3795 - accuracy: 0.8967
# Epoch 7/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.9167
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2974 - accuracy: 0.9400
# Epoch 9/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2595 - accuracy: 0.9467
# Epoch 10/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2265 - accuracy: 0.9533
# Epoch 11/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1957 - accuracy: 0.9600
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1692 - accuracy: 0.9633
# Epoch 13/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9733
# Epoch 14/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9833
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9833
# Epoch 16/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1069 - accuracy: 0.9833
# Epoch 17/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 0.9833
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0909 - accuracy: 0.9833
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9833
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.9833
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9833
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9833
# Epoch 23/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0758 - accuracy: 0.9833
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9833
# Epoch 25/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9833
# Epoch 26/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9833
# Epoch 27/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9833
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9833
# Epoch 29/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9833
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9833
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9833
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9833
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9833
# Epoch 34/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9833
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 0.9833
# Epoch 36/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9833
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 0.9833
# Epoch 38/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0669 - accuracy: 0.9833
# Epoch 39/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9833
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0712 - accuracy: 0.9833
# Epoch 41/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9833
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9833
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9833
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 0.9833
# Epoch 45/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0655 - accuracy: 0.9833
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 0.9833
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 0.9833
# Epoch 48/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9833
# Epoch 49/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9833
# Epoch 50/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0636 - accuracy: 0.9833
# Epoch 51/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0626 - accuracy: 0.9833
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9833
# Epoch 53/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9833
# Epoch 54/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9833
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 0.9833
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0622 - accuracy: 0.9833
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9833
# Epoch 58/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 0.9833
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 0.9833
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0583 - accuracy: 0.9833
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9833
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9833
# Epoch 63/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 0.9833
# Epoch 64/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 0.9833
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 0.9833
# Epoch 66/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0598 - accuracy: 0.9833
# Epoch 67/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0601 - accuracy: 0.9833
# Epoch 68/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0586 - accuracy: 0.9833
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9833
# Epoch 70/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 0.9833
# Epoch 71/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0571 - accuracy: 0.9833
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9833
# Epoch 73/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0604 - accuracy: 0.9833
# Epoch 74/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0559 - accuracy: 0.9833
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0585 - accuracy: 0.9833
# Epoch 76/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0575 - accuracy: 0.9833
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9833
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9833
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 0.9833
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9833
# Epoch 81/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9833
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9833
# Epoch 83/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9833
# Epoch 84/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0642 - accuracy: 0.9800
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9833
# Epoch 86/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0548 - accuracy: 0.9833
# Epoch 87/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0547 - accuracy: 0.9833
# Epoch 88/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9833
# Epoch 89/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0531 - accuracy: 0.9833
# Epoch 90/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9833
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9833
# Epoch 92/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0519 - accuracy: 0.9833
# Epoch 93/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9833
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9833
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0526 - accuracy: 0.9833
# Epoch 96/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 0.9833
# Epoch 97/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0528 - accuracy: 0.9833
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9833
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0566 - accuracy: 0.9867
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9833
# 3/3 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      0.90      0.95        39
#     Demanted       0.89      1.00      0.94        34
#
#     accuracy                           0.95        73
#    macro avg       0.95      0.95      0.95        73
# weighted avg       0.95      0.95      0.95        73

# %% [markdown]
# ### RNN LSTM

# %%
def build_lstm_rnn():
    lstm_rnn = tf.keras.Sequential()
    lstm_rnn.add(tf.keras.layers.LSTM(100, return_sequences = True,input_shape = (X_train.shape[1],1) ) )
    lstm_rnn.add(tf.keras.layers.LSTM(50,return_sequences = False))
    lstm_rnn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    lstm_rnn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return lstm_rnn

# %%
lstm_rnn = build_lstm_rnn()
lstm_rnn.fit(X_train, y_train, epochs = 100)
not_final_lstm_rnn_prediction = lstm_rnn.predict(X_test)
lstm_rnn_prediction = np.where(not_final_lstm_rnn_prediction > 0.5, 1, 0)
print(classification_report(y_test,lstm_rnn_prediction, target_names= ["Non-Demanted", "Demanted"]))
lstm_rnn_conf = confusion_matrix(y_test,lstm_rnn_prediction)
model_details.append(["LSTM RNN", round(f1_score(y_test,lstm_rnn_prediction, average = "weighted") * 100,4),lstm_rnn_conf[1,0]])
lstm_rnn_plot_conf = ConfusionMatrixDisplay(lstm_rnn_conf)
lstm_rnn_plot_conf.plot()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 4s 9ms/step - loss: 0.6899 - accuracy: 0.5800
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6815 - accuracy: 0.5800
# Epoch 3/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6829 - accuracy: 0.6067
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6744 - accuracy: 0.5800
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6734 - accuracy: 0.5933
# Epoch 6/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6822 - accuracy: 0.5900
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6677 - accuracy: 0.6233
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6647 - accuracy: 0.6133
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6488 - accuracy: 0.6467
# Epoch 10/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6348 - accuracy: 0.6467
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6152 - accuracy: 0.7100
# Epoch 12/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6023 - accuracy: 0.6733
# Epoch 13/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6079 - accuracy: 0.6800
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5904 - accuracy: 0.7200
# Epoch 15/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6075 - accuracy: 0.6867
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5860 - accuracy: 0.7100
# Epoch 17/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6039 - accuracy: 0.6567
# Epoch 18/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.5889 - accuracy: 0.7400
# Epoch 19/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5801 - accuracy: 0.7200
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5577 - accuracy: 0.7333
# Epoch 21/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5649 - accuracy: 0.7233
# Epoch 22/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5528 - accuracy: 0.7267
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5765 - accuracy: 0.6933
# Epoch 24/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5360 - accuracy: 0.7567
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4889 - accuracy: 0.7867
# Epoch 26/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4469 - accuracy: 0.8333
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5419 - accuracy: 0.7000
# Epoch 28/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4375 - accuracy: 0.8400
# Epoch 29/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4057 - accuracy: 0.8533
# Epoch 30/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3738 - accuracy: 0.8400
# Epoch 31/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3392 - accuracy: 0.8633
# Epoch 32/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4401 - accuracy: 0.7800
# Epoch 33/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.4011 - accuracy: 0.7967
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3441 - accuracy: 0.8700
# Epoch 35/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.3213 - accuracy: 0.8833
# Epoch 36/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.2684 - accuracy: 0.8967
# Epoch 37/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2782 - accuracy: 0.8800
# Epoch 38/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2498 - accuracy: 0.9133
# Epoch 39/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2897 - accuracy: 0.8833
# Epoch 40/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.3258 - accuracy: 0.8600
# Epoch 41/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2598 - accuracy: 0.9033
# Epoch 42/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.2293 - accuracy: 0.9333
# Epoch 43/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2191 - accuracy: 0.9200
# Epoch 44/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1945 - accuracy: 0.9400
# Epoch 45/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1928 - accuracy: 0.9333
# Epoch 46/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1995 - accuracy: 0.9100
# Epoch 47/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2008 - accuracy: 0.9233
# Epoch 48/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1802 - accuracy: 0.9433
# Epoch 49/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1878 - accuracy: 0.9333
# Epoch 50/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.2256 - accuracy: 0.9200
# Epoch 51/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2004 - accuracy: 0.9367
# Epoch 52/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1779 - accuracy: 0.9500
# Epoch 53/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1569 - accuracy: 0.9500
# Epoch 54/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1591 - accuracy: 0.9633
# Epoch 55/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1288 - accuracy: 0.9567
# Epoch 56/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1445 - accuracy: 0.9533
# Epoch 57/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1227 - accuracy: 0.9733
# Epoch 58/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1213 - accuracy: 0.9733
# Epoch 59/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1241 - accuracy: 0.9600
# Epoch 60/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1447 - accuracy: 0.9467
# Epoch 61/100
# 10/10 [==============================] - 0s 16ms/step - loss: 0.1072 - accuracy: 0.9700
# Epoch 62/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1032 - accuracy: 0.9800
# Epoch 63/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.1058 - accuracy: 0.9733
# Epoch 64/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0862 - accuracy: 0.9833
# Epoch 65/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0942 - accuracy: 0.9800
# Epoch 66/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0828 - accuracy: 0.9800
# Epoch 67/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0887 - accuracy: 0.9833
# Epoch 68/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0799 - accuracy: 0.9833
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0903 - accuracy: 0.9767
# Epoch 70/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0924 - accuracy: 0.9800
# Epoch 71/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1072 - accuracy: 0.9700
# Epoch 72/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1671 - accuracy: 0.9433
# Epoch 73/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1426 - accuracy: 0.9433
# Epoch 74/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1152 - accuracy: 0.9600
# Epoch 75/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1031 - accuracy: 0.9700
# Epoch 76/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0794 - accuracy: 0.9800
# Epoch 77/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0758 - accuracy: 0.9833
# Epoch 78/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0751 - accuracy: 0.9833
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0715 - accuracy: 0.9800
# Epoch 80/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0728 - accuracy: 0.9800
# Epoch 81/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0702 - accuracy: 0.9833
# Epoch 82/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0717 - accuracy: 0.9833
# Epoch 83/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0677 - accuracy: 0.9833
# Epoch 84/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0685 - accuracy: 0.9833
# Epoch 85/100
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0707 - accuracy: 0.9833
# Epoch 86/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0742 - accuracy: 0.9800
# Epoch 87/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0894 - accuracy: 0.9767
# Epoch 88/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0762 - accuracy: 0.9833
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0676 - accuracy: 0.9800
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0668 - accuracy: 0.9833
# Epoch 91/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0675 - accuracy: 0.9833
# Epoch 92/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0634 - accuracy: 0.9833
# Epoch 93/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0631 - accuracy: 0.9833
# Epoch 94/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0626 - accuracy: 0.9833
# Epoch 95/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0637 - accuracy: 0.9800
# Epoch 96/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9833
# Epoch 97/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 0.9833
# Epoch 98/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0632 - accuracy: 0.9833
# Epoch 99/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0640 - accuracy: 0.9800
# Epoch 100/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0666 - accuracy: 0.9833
# 3/3 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      0.90      0.95        39
#     Demanted       0.89      1.00      0.94        34
#
#     accuracy                           0.95        73
#    macro avg       0.95      0.95      0.95        73
# weighted avg       0.95      0.95      0.95        73

# %% [markdown]
# ### RNN GRU

# %%
def build_gru_rnn():
    gru_rnn = tf.keras.Sequential()
    gru_rnn.add(tf.keras.layers.GRU(100, return_sequences = True,input_shape = (X_train.shape[1],1) ) )
    gru_rnn.add(tf.keras.layers.GRU(50,return_sequences = False))
    gru_rnn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    gru_rnn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return gru_rnn

# %%
gru_rnn = build_gru_rnn()
gru_rnn.fit(X_train, y_train, epochs = 100)
not_final_gru_rnn_prediction = gru_rnn.predict(X_test)
gru_rnn_prediction = np.where(not_final_gru_rnn_prediction > 0.5, 1, 0)
print(classification_report(y_test,gru_rnn_prediction, target_names= ["Non-Demanted", "Demanted"]))
gru_rnn_conf = confusion_matrix(y_test,gru_rnn_prediction)
model_details.append(["GRU RNN", round(f1_score(y_test,gru_rnn_prediction, average = "weighted") * 100,4),gru_rnn_conf[1,0]])
gru_rnn_plot_conf = ConfusionMatrixDisplay(gru_rnn_conf)
gru_rnn_plot_conf.plot()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 4s 9ms/step - loss: 0.6907 - accuracy: 0.5800
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6867 - accuracy: 0.5800
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6774 - accuracy: 0.5800
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6711 - accuracy: 0.5800
# Epoch 5/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6626 - accuracy: 0.6200
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6455 - accuracy: 0.6033
# Epoch 7/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6188 - accuracy: 0.7233
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5858 - accuracy: 0.7167
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5669 - accuracy: 0.7067
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5262 - accuracy: 0.7433
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4517 - accuracy: 0.8400
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3909 - accuracy: 0.8467
# Epoch 13/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3081 - accuracy: 0.8933
# Epoch 14/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2647 - accuracy: 0.9100
# Epoch 15/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2071 - accuracy: 0.9433
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1712 - accuracy: 0.9467
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1448 - accuracy: 0.9733
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1298 - accuracy: 0.9733
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1236 - accuracy: 0.9800
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1401 - accuracy: 0.9767
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1133 - accuracy: 0.9800
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1070 - accuracy: 0.9800
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1041 - accuracy: 0.9800
# Epoch 24/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1066 - accuracy: 0.9800
# Epoch 25/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1019 - accuracy: 0.9833
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1020 - accuracy: 0.9833
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1145 - accuracy: 0.9800
# Epoch 28/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0977 - accuracy: 0.9833
# Epoch 29/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0942 - accuracy: 0.9833
# Epoch 30/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0919 - accuracy: 0.9833
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0935 - accuracy: 0.9833
# Epoch 32/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0982 - accuracy: 0.9800
# Epoch 33/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0904 - accuracy: 0.9833
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0895 - accuracy: 0.9833
# Epoch 35/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0869 - accuracy: 0.9833
# Epoch 36/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0899 - accuracy: 0.9833
# Epoch 37/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0971 - accuracy: 0.9800
# Epoch 38/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0981 - accuracy: 0.9833
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0850 - accuracy: 0.9833
# Epoch 40/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0833 - accuracy: 0.9833
# Epoch 41/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0861 - accuracy: 0.9833
# Epoch 42/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0865 - accuracy: 0.9833
# Epoch 43/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0903 - accuracy: 0.9800
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0875 - accuracy: 0.9833
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0888 - accuracy: 0.9833
# Epoch 46/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0843 - accuracy: 0.9833
# Epoch 47/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0842 - accuracy: 0.9833
# Epoch 48/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0829 - accuracy: 0.9833
# Epoch 49/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0779 - accuracy: 0.9833
# Epoch 50/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0789 - accuracy: 0.9833
# Epoch 51/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0834 - accuracy: 0.9800
# Epoch 52/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0732 - accuracy: 0.9833
# Epoch 53/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0726 - accuracy: 0.9833
# Epoch 54/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0724 - accuracy: 0.9833
# Epoch 55/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0708 - accuracy: 0.9833
# Epoch 56/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0733 - accuracy: 0.9800
# Epoch 57/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0726 - accuracy: 0.9833
# Epoch 58/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0836 - accuracy: 0.9833
# Epoch 59/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0678 - accuracy: 0.9833
# Epoch 60/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0831 - accuracy: 0.9833
# Epoch 61/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0830 - accuracy: 0.9867
# Epoch 62/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0853 - accuracy: 0.9733
# Epoch 63/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1056 - accuracy: 0.9767
# Epoch 64/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0825 - accuracy: 0.9767
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0702 - accuracy: 0.9833
# Epoch 66/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0786 - accuracy: 0.9833
# Epoch 67/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0757 - accuracy: 0.9833
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0673 - accuracy: 0.9833
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0692 - accuracy: 0.9867
# Epoch 70/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0717 - accuracy: 0.9833
# Epoch 71/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0668 - accuracy: 0.9833
# Epoch 72/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0662 - accuracy: 0.9833
# Epoch 73/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0629 - accuracy: 0.9833
# Epoch 74/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0596 - accuracy: 0.9833
# Epoch 75/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 0.9833
# Epoch 76/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0709 - accuracy: 0.9833
# Epoch 77/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0755 - accuracy: 0.9733
# Epoch 78/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0676 - accuracy: 0.9833
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0581 - accuracy: 0.9867
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0576 - accuracy: 0.9833
# Epoch 81/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0551 - accuracy: 0.9800
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0564 - accuracy: 0.9833
# Epoch 83/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0547 - accuracy: 0.9833
# Epoch 84/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0529 - accuracy: 0.9867
# Epoch 85/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0529 - accuracy: 0.9833
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0570 - accuracy: 0.9833
# Epoch 87/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0872 - accuracy: 0.9800
# Epoch 88/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0675 - accuracy: 0.9700
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0664 - accuracy: 0.9833
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0590 - accuracy: 0.9800
# Epoch 91/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0536 - accuracy: 0.9833
# Epoch 92/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0473 - accuracy: 0.9867
# Epoch 93/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0615 - accuracy: 0.9800
# Epoch 94/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0556 - accuracy: 0.9833
# Epoch 95/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0452 - accuracy: 0.9867
# Epoch 96/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0481 - accuracy: 0.9867
# Epoch 97/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0494 - accuracy: 0.9833
# Epoch 98/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0562 - accuracy: 0.9833
# Epoch 99/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0483 - accuracy: 0.9833
# Epoch 100/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0494 - accuracy: 0.9867
# 3/3 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      0.90      0.95        39
#     Demanted       0.89      1.00      0.94        34
#
#     accuracy                           0.95        73
#    macro avg       0.95      0.95      0.95        73
# weighted avg       0.95      0.95      0.95        73

# %% [markdown]
# ## Result

# %%
models = pd.DataFrame(model_details, columns = ["model","score","false_negatives"])
models = models.sort_values(["false_negatives"]).reset_index(drop = True)
models
# Out:
#                     model    score  false_negatives
# 0      LogisticRegression  94.5247                0
# 1  RandomForestClassifier  94.5247                0
# 2               LinearSVC  94.5247                0
# 3                     SNN  94.5247                0
# 4                LSTM RNN  94.5247                0
# 5                 GRU RNN  94.5247                0

# %%
models.to_csv(f"v3_details_random_state_{RANDOM_STATE}.csv", index = False)

# %%
# Author: amyrmahdy
# Date: 20 Dec 2022
