# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.svm import LinearSVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupShuffleSplit
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.metrics import f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Reading

# %%
df = pd.read_csv("oasis_longitudinal.csv")

# %% [markdown]
# ### Set random state

# %%
RANDOM_STATE = 13

# %% [markdown]
# ## EDA

# %%
# MR Delay
# after how many days visit based on first visit

# EDUC
# How many years educate

# SES
# Socioeconomic Status
# 5 means LOW and 1 means HIGH?

# MMSE
# Mini‐Mental State Examination

# CDR
# Clinical Dementia Rating

# eTIV
# Estimated total intracranial volume

# nWBV
# Normalize Whole Brain Volume

# ASF
# Atlas Scaling Factor

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df.tail()
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 368    16  1.0  28.0  0.5  1693  0.694  1.037
# 369    16  1.0  26.0  0.5  1688  0.675  1.040
# 370    13  2.0  30.0  0.0  1319  0.801  1.331
# 371    13  2.0  30.0  0.0  1327  0.796  1.323
# 372    13  2.0  30.0  0.0  1333  0.801  1.317

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subject ID  373 non-null    object
#  1   MRI ID      373 non-null    object
#  2   Group       373 non-null    object
#  3   Visit       373 non-null    int64
#  4   MR Delay    373 non-null    int64
#  5   M/F         373 non-null    object
#  6   Hand        373 non-null    object
#  7   Age         373 non-null    int64
#  8   EDUC        373 non-null    int64
#  9   SES         354 non-null    float64
#  10  MMSE        371 non-null    float64
#  11  CDR         373 non-null    float64
#  12  eTIV        373 non-null    int64
#  13  nWBV        373 non-null    float64
#  14  ASF         373 non-null    float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 43.8+ KB

# %%
df.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  373.000000   373.000000  373.000000  373.000000  354.000000
# mean     1.882038   595.104558   77.013405   14.597855    2.460452
# std      0.922843   635.485118    7.640957    2.876339    1.134005
# min      1.000000     0.000000   60.000000    6.000000    1.000000
# 25%      1.000000     0.000000   71.000000   12.000000    2.000000
# 50%      2.000000   552.000000   77.000000   15.000000    2.000000
# 75%      2.000000   873.000000   82.000000   16.000000    3.000000
# max      5.000000  2639.000000   98.000000   23.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  371.000000  373.000000   373.000000  373.000000  373.000000
# mean    27.342318    0.290885  1488.128686    0.729568    1.195461
# std      3.683244    0.374557   176.139286    0.037135    0.138092
# min      4.000000    0.000000  1106.000000    0.644000    0.876000
# 25%     27.000000    0.000000  1357.000000    0.700000    1.099000
# 50%     29.000000    0.000000  1470.000000    0.729000    1.194000
# 75%     30.000000    0.500000  1597.000000    0.756000    1.293000
# max     30.000000    2.000000  2004.000000    0.837000    1.587000

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Handeling SES nan values

# %%
df.SES.hist(figsize = (10,5))
# Out:
# <AxesSubplot: >

# %%
df.SES.mean()
# Out:
# 2.4604519774011298

# %%
df.SES.unique()
# Out:
# array([ 2., nan,  3.,  4.,  1.,  5.])

# %%
df.groupby(["SES"]).mean()
# Out:
# /tmp/ipykernel_15276/2585948393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["SES"]).mean()
#         Visit    MR Delay        Age       EDUC       MMSE       CDR  \
# SES
# 1.0  2.011364  672.181818  77.829545  17.340909  27.602273  0.301136
# 2.0  1.815534  562.961165  76.679612  15.446602  28.067961  0.179612
# 3.0  1.865854  555.634146  77.243902  13.987805  27.573171  0.280488
# 4.0  1.864865  632.851351  76.243243  11.959459  26.378378  0.337838
# 5.0  1.714286  478.428571  78.142857   8.000000  24.285714  0.428571
#
#             eTIV      nWBV       ASF
# SES
# 1.0  1571.204545  0.716614  1.131739
# 2.0  1489.339806  0.735223  1.195087
# 3.0  1442.573171  0.741890  1.229829
# 4.0  1460.202703  0.725595  1.214378
# 5.0  1349.000000  0.722571  1.314429

# %%
# fill nan values function for SES
def fill_ses(x):
    ses = 0
    if x > 17:
        ses = 1.0
    elif (x < 17) and (x > 15):
        ses = 2.0
    elif (x < 15) and (x > 13):
        ses = 3.0
    elif (x < 13) and (x > 11):
        ses = 4.0
    else:
        ses = 5.0
    return ses

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df["SES"] = df.apply(lambda x : fill_ses(x.EDUC) if pd.isna(x.SES)   else x.SES, axis = 1)

# %%
# convert float to int to use less memory
df["SES"] = df.SES.astype(int)

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    2  27.0  0.0  1987  0.696  0.883
# 1    2  30.0  0.0  2004  0.681  0.876
# 2    4  23.0  0.5  1678  0.736  1.046
# 3    4  28.0  0.5  1738  0.713  1.010
# 4    4  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# ### Handeling MMSE nan values

# %%
df.MMSE.hist()
# Out:
# <AxesSubplot: >

# %%
df.groupby(["MMSE"]).mean()
# Out:
# /tmp/ipykernel_15276/685721936.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["MMSE"]).mean()
#          Visit     MR Delay        Age       EDUC       SES       CDR  \
# MMSE
# 4.0   5.000000  1233.000000  69.000000  16.000000  1.000000  1.000000
# 7.0   4.000000   970.000000  68.000000  16.000000  1.000000  1.000000
# 15.0  2.000000   473.500000  73.500000  14.000000  3.500000  1.500000
# 16.0  2.333333   841.000000  73.666667  13.333333  3.666667  1.000000
# 17.0  1.800000   524.000000  70.000000  12.800000  3.200000  0.800000
# 18.0  2.500000  1023.000000  78.500000  10.000000  3.500000  0.750000
# 19.0  1.666667   215.666667  69.000000  14.666667  1.333333  1.000000
# 20.0  1.571429   372.857143  78.428571  13.285714  3.000000  0.714286
# 21.0  1.545455   315.636364  78.181818  14.181818  3.000000  0.909091
# 22.0  2.000000   646.285714  75.571429  13.142857  3.285714  0.714286
# 23.0  1.363636   247.090909  78.727273  11.727273  3.363636  0.636364
# 24.0  1.750000   516.000000  80.000000  14.500000  2.250000  0.500000
# 25.0  1.500000   380.333333  76.666667  14.250000  2.416667  0.625000
# 26.0  1.750000   633.150000  79.300000  14.850000  2.900000  0.500000
# 27.0  1.968750   529.843750  79.093750  13.187500  2.843750  0.453125
# 28.0  1.866667   597.933333  77.222222  14.533333  2.466667  0.222222
# 29.0  1.846154   612.197802  77.593407  15.219780  2.395604  0.109890
# 30.0  1.982456   676.798246  75.947368  15.228070  2.245614  0.078947
#
#              eTIV      nWBV       ASF
# MMSE
# 4.0   1701.000000  0.676000  1.032000
# 7.0   1714.000000  0.682000  1.024000
# 15.0  1366.000000  0.689000  1.285500
# 16.0  1520.000000  0.705667  1.156000
# 17.0  1569.000000  0.701400  1.122600
# 18.0  1471.500000  0.669500  1.193000
# 19.0  1560.333333  0.710000  1.146000
# 20.0  1555.000000  0.700429  1.138000
# 21.0  1439.000000  0.683727  1.232091
# 22.0  1456.857143  0.713286  1.221286
# 23.0  1545.636364  0.714727  1.141273
# 24.0  1355.000000  0.720750  1.299250
# 25.0  1481.916667  0.727167  1.210000
# 26.0  1472.650000  0.718150  1.210000
# 27.0  1449.281250  0.729656  1.224156
# 28.0  1497.088889  0.737422  1.188222
# 29.0  1476.747253  0.734220  1.205967
# 30.0  1507.614035  0.738833  1.179246

# %%
df["MMSE"].mean()
# Out:
# 27.342318059299192

# %%
df["MMSE"].median()
# Out:
# 29.0

# %%
df[df["MMSE"].isna()]
# Out:
#     Subject ID         MRI ID     Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 357  OAS2_0181  OAS2_0181_MR2  Demented      2       539   F    R   75    12
# 358  OAS2_0181  OAS2_0181_MR3  Demented      3      1107   F    R   77    12
#
#      SES  MMSE  CDR  eTIV   nWBV    ASF
# 357    4   NaN  1.0  1169  0.742  1.501
# 358    4   NaN  1.0  1159  0.733  1.515

# %%
df[df["Group"] == "Demented"]["MMSE"].median()
# Out:
# 26.0

# %%
df[df["MMSE"] < 26]["Group"].unique()
# Out:
# array(['Demented', 'Converted'], dtype=object)

# %%
df["MMSE"] = df.MMSE.fillna(df[df["Group"] == "Demented"]["MMSE"].median())

# %% [markdown]
# ### Replace M/F values

# %%
df["M/F"] = np.where(df["M/F"] == "M", 1, 0)

# %% [markdown]
# ### Drop Hand & MRI ID

# %%
df.drop(["Hand", "MRI ID"], axis = 1, inplace = True)

# %% [markdown]
# ### Handeling Visits

# %%
# 11
df.iloc[10:13,:]
# Out:
#    Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 10  OAS2_0007  Demented      1         0    1   71    16    2  28.0  0.5
# 11  OAS2_0007  Demented      3       518    1   73    16    2  27.0  1.0
# 12  OAS2_0007  Demented      4      1281    1   75    16    2  27.0  1.0
#
#     eTIV   nWBV    ASF
# 10  1357  0.748  1.293
# 11  1365  0.727  1.286
# 12  1372  0.710  1.279

# %%
# 11
df.loc[11,'Visit'] = 2
df.loc[12,'Visit'] = 3
df.iloc[10:13,:]
# Out:
#    Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 10  OAS2_0007  Demented      1         0    1   71    16    2  28.0  0.5
# 11  OAS2_0007  Demented      2       518    1   73    16    2  27.0  1.0
# 12  OAS2_0007  Demented      3      1281    1   75    16    2  27.0  1.0
#
#     eTIV   nWBV    ASF
# 10  1357  0.748  1.293
# 11  1365  0.727  1.286
# 12  1372  0.710  1.279

# %%
# 30
df.iloc[29:33,:]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 29  OAS2_0017  Nondemented      1         0    1   80    12    3  29.0  0.0
# 30  OAS2_0017  Nondemented      3       617    1   81    12    3  27.0  0.5
# 31  OAS2_0017  Nondemented      4      1861    1   85    12    3  30.0  0.0
# 32  OAS2_0017  Nondemented      5      2400    1   86    12    3  27.0  0.0
#
#     eTIV   nWBV    ASF
# 29  1783  0.752  0.985
# 30  1814  0.759  0.968
# 31  1820  0.755  0.964
# 32  1813  0.761  0.968

# %%
# 30
df.loc[30,'Visit'] = 2
df.loc[31,'Visit'] = 3
df.loc[32,'Visit'] = 4
df.iloc[29:33,:]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 29  OAS2_0017  Nondemented      1         0    1   80    12    3  29.0  0.0
# 30  OAS2_0017  Nondemented      2       617    1   81    12    3  27.0  0.5
# 31  OAS2_0017  Nondemented      3      1861    1   85    12    3  30.0  0.0
# 32  OAS2_0017  Nondemented      4      2400    1   86    12    3  27.0  0.0
#
#     eTIV   nWBV    ASF
# 29  1783  0.752  0.985
# 30  1814  0.759  0.968
# 31  1820  0.755  0.964
# 32  1813  0.761  0.968

# %%
# 34
df.iloc[33:36,:]
# Out:
#    Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 33  OAS2_0018  Converted      1         0    0   87    14    1  30.0  0.0
# 34  OAS2_0018  Converted      3       489    0   88    14    1  29.0  0.0
# 35  OAS2_0018  Converted      4      1933    0   92    14    1  27.0  0.5
#
#     eTIV   nWBV    ASF
# 33  1406  0.715  1.248
# 34  1398  0.713  1.255
# 35  1423  0.696  1.234

# %%
# 34
df.loc[34,'Visit'] = 2
df.loc[35,'Visit'] = 3
df.iloc[33:36,:]
# Out:
#    Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 33  OAS2_0018  Converted      1         0    0   87    14    1  30.0  0.0
# 34  OAS2_0018  Converted      2       489    0   88    14    1  29.0  0.0
# 35  OAS2_0018  Converted      3      1933    0   92    14    1  27.0  0.5
#
#     eTIV   nWBV    ASF
# 33  1406  0.715  1.248
# 34  1398  0.713  1.255
# 35  1423  0.696  1.234

# %%
# 69
df.iloc[68:71]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 68  OAS2_0036  Nondemented      1         0    0   69    13    4  30.0  0.0
# 69  OAS2_0036  Nondemented      3       713    0   70    13    4  30.0  0.0
# 70  OAS2_0036  Nondemented      4      1770    0   73    13    4  30.0  0.0
#
#     eTIV   nWBV    ASF
# 68  1359  0.789  1.291
# 69  1361  0.783  1.290
# 70  1360  0.773  1.291

# %%
# 69
df.loc[69,'Visit'] = 2
df.loc[70,'Visit'] = 3
df.iloc[68:71]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 68  OAS2_0036  Nondemented      1         0    0   69    13    4  30.0  0.0
# 69  OAS2_0036  Nondemented      2       713    0   70    13    4  30.0  0.0
# 70  OAS2_0036  Nondemented      3      1770    0   73    13    4  30.0  0.0
#
#     eTIV   nWBV    ASF
# 68  1359  0.789  1.291
# 69  1361  0.783  1.290
# 70  1360  0.773  1.291

# %%
# 188
df.iloc[187:189]
# Out:
#     Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 187  OAS2_0089  Demented      1         0    1   70    12    2  29.0  0.5
# 188  OAS2_0089  Demented      3       563    1   72    12    2  27.0  1.0
#
#      eTIV   nWBV    ASF
# 187  1432  0.692  1.225
# 188  1432  0.684  1.226

# %%
# 188
df.loc[188,'Visit'] = 2
df.iloc[187:189]
# Out:
#     Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 187  OAS2_0089  Demented      1         0    1   70    12    2  29.0  0.5
# 188  OAS2_0089  Demented      2       563    1   72    12    2  27.0  1.0
#
#      eTIV   nWBV    ASF
# 187  1432  0.692  1.225
# 188  1432  0.684  1.226

# %%
# 274
df.iloc[273:275]
# Out:
#     Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 273  OAS2_0133  Converted      1         0    0   78    12    3  29.0  0.0
# 274  OAS2_0133  Converted      3      1006    0   81    12    3  28.0  0.5
#
#      eTIV   nWBV    ASF
# 273  1475  0.731  1.190
# 274  1495  0.687  1.174

# %%
# 274
df.loc[274,'Visit'] = 2
df.iloc[273:275]
# Out:
#     Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 273  OAS2_0133  Converted      1         0    0   78    12    3  29.0  0.0
# 274  OAS2_0133  Converted      2      1006    0   81    12    3  28.0  0.5
#
#      eTIV   nWBV    ASF
# 273  1475  0.731  1.190
# 274  1495  0.687  1.174

# %% [markdown]
# ### Cut only firsts and seconds and third visits

# %%
df_copy = df.copy()

# %%
has_third_subject_id = df[df["Visit"] == 3]["Subject ID"].values

# %%
df = df[df['Subject ID'].isin(has_third_subject_id)]

# %%
visit_3 = df[df["Visit"] == 3]

# %%
visit_3
# Out:
#     Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 4    OAS2_0002     Demented      3      1895    1   80    12    4  22.0  0.5
# 9    OAS2_0005  Nondemented      3      1603    1   85    12    4  30.0  0.0
# 12   OAS2_0007     Demented      3      1281    1   75    16    2  27.0  1.0
# 21   OAS2_0012  Nondemented      3      1598    0   83    16    2  29.0  0.0
# 24   OAS2_0013  Nondemented      3      1456    0   85    12    4  29.0  0.0
# 31   OAS2_0017  Nondemented      3      1861    1   85    12    3  30.0  0.0
# 35   OAS2_0018    Converted      3      1933    0   92    14    1  27.0  0.5
# 38   OAS2_0020    Converted      3      1563    1   84    20    1  26.0  0.5
# 49   OAS2_0027  Nondemented      3      1234    0   73    12    3  30.0  0.0
# 59   OAS2_0031    Converted      3      1588    0   91    12    3  28.0  0.5
# 64   OAS2_0034  Nondemented      3      1287    0   82    16    1  30.0  0.0
# 70   OAS2_0036  Nondemented      3      1770    0   73    13    4  30.0  0.0
# 74   OAS2_0037     Demented      3      2029    1   88    12    4  26.0  0.5
# 80   OAS2_0040     Demented      3      1204    1   88     6    4  23.0  0.5
# 83   OAS2_0041    Converted      3      1331    0   75    16    1  28.0  0.5
# 90   OAS2_0044     Demented      3       866    1   71    14    4  22.0  1.0
# 99   OAS2_0048     Demented      3       647    1   68    16    1  19.0  1.0
# 104  OAS2_0049  Nondemented      3       687    0   71    16    3  30.0  0.0
# 109  OAS2_0051  Nondemented      3      1526    0   97    23    1  30.0  0.0
# 122  OAS2_0057  Nondemented      3      1340    0   85    12    2  30.0  0.0
# 125  OAS2_0058     Demented      3       764    1   80    14    3  29.0  0.5
# 130  OAS2_0061  Nondemented      3      1651    1   72    18    1  30.0  0.0
# 133  OAS2_0062  Nondemented      3      1351    0   83    18    2  29.0  0.0
# 138  OAS2_0064     Demented      3      1282    0   82     8    5  18.0  0.5
# 143  OAS2_0067  Nondemented      3      1438    1   71    12    4  29.0  0.0
# 151  OAS2_0070  Nondemented      3      1415    1   84    17    1  29.0  0.0
# 158  OAS2_0073  Nondemented      3      1705    0   75    14    3  28.0  0.0
# 165  OAS2_0076  Nondemented      3      1663    0   71    18    2  30.0  0.0
# 170  OAS2_0078  Nondemented      3      1019    1   92    16    1  30.0  0.0
# 173  OAS2_0079     Demented      3      1435    0   73    12    4  16.0  1.0
# 176  OAS2_0080     Demented      3      1209    1   69    15    2  28.0  0.5
# 191  OAS2_0090  Nondemented      3      1345    1   76    18    2  30.0  0.0
# 200  OAS2_0095  Nondemented      3      1412    1   74    18    1  29.0  0.0
# 211  OAS2_0100  Nondemented      3      1752    0   82    11    4  30.0  0.0
# 214  OAS2_0101  Nondemented      3      1631    0   76    18    2  30.0  0.0
# 217  OAS2_0102     Demented      3      1387    1   86    15    3  30.0  0.5
# 220  OAS2_0103    Converted      3      2002    0   75    16    1  30.0  0.5
# 243  OAS2_0117  Nondemented      3      1345    1   76    20    2  30.0  0.0
# 249  OAS2_0119  Nondemented      3      1713    0   85    15    2  30.0  0.0
# 260  OAS2_0126  Nondemented      3      1192    0   77    12    3  29.0  0.0
# 263  OAS2_0127    Converted      3      1042    1   81    18    1  29.0  0.5
# 270  OAS2_0129  Nondemented      3      1591    0   82    18    1  29.0  0.0
# 287  OAS2_0140     Demented      3      1655    0   81    16    3  25.0  0.5
# 294  OAS2_0143  Nondemented      3      1553    0   93    18    2  29.0  0.0
# 303  OAS2_0147  Nondemented      3      1204    0   80    13    2  28.0  0.0
# 311  OAS2_0152  Nondemented      3      1329    0   69    18    2  29.0  0.0
# 326  OAS2_0161  Nondemented      3      1033    1   80    16    1  29.0  0.0
# 337  OAS2_0171  Nondemented      3      1695    1   81    16    3  30.0  0.0
# 342  OAS2_0174  Nondemented      3      1555    1   64    12    4  30.0  0.0
# 345  OAS2_0175     Demented      3      1343    1   73    16    4  28.0  0.5
# 348  OAS2_0176    Converted      3      1631    1   89    16    2  30.0  0.5
# 353  OAS2_0178  Nondemented      3      1447    0   93    14    2  30.0  0.0
# 358  OAS2_0181     Demented      3      1107    0   77    12    4  26.0  1.0
# 363  OAS2_0183  Nondemented      3       732    0   68    13    2  30.0  0.0
# 369  OAS2_0185     Demented      3      2297    1   86    16    1  26.0  0.5
# 372  OAS2_0186  Nondemented      3      1608    0   65    13    2  30.0  0.0
#
#      eTIV   nWBV    ASF
# 4    1698  0.701  1.034
# 9    1699  0.705  1.033
# 12   1372  0.710  1.279
# 21   1323  0.718  1.327
# 24   1225  0.710  1.433
# 31   1820  0.755  0.964
# 35   1423  0.696  1.234
# 38   1597  0.666  1.099
# 49   1358  0.775  1.293
# 59   1463  0.696  1.199
# 64   1460  0.695  1.202
# 70   1360  0.773  1.291
# 74   1483  0.709  1.184
# 80   1348  0.713  1.302
# 83   1314  0.760  1.335
# 90   1332  0.679  1.317
# 99   1712  0.691  1.025
# 104  1503  0.788  1.168
# 109  1483  0.689  1.184
# 122  1580  0.739  1.111
# 125  1324  0.695  1.326
# 130  1681  0.729  1.044
# 133  1667  0.688  1.053
# 138  1464  0.682  1.199
# 143  1455  0.724  1.206
# 151  1707  0.717  1.028
# 158  1507  0.782  1.164
# 165  1520  0.718  1.155
# 170  1662  0.682  1.056
# 173  1478  0.696  1.188
# 176  1546  0.724  1.135
# 191  1550  0.758  1.133
# 200  1814  0.679  0.967
# 211  1590  0.760  1.104
# 214  1379  0.757  1.273
# 217  1498  0.681  1.171
# 220  1419  0.731  1.236
# 243  1823  0.739  0.963
# 249  1488  0.741  1.180
# 260  1344  0.740  1.306
# 263  1647  0.717  1.066
# 270  1442  0.644  1.217
# 287  1396  0.687  1.257
# 294  1744  0.723  1.006
# 303  1337  0.762  1.313
# 311  1202  0.770  1.461
# 326  1830  0.724  0.959
# 337  1836  0.744  0.956
# 342  1370  0.794  1.281
# 345  1803  0.731  0.973
# 348  1408  0.679  1.246
# 353  1488  0.735  1.179
# 358  1159  0.733  1.515
# 363  1506  0.740  1.165
# 369  1688  0.675  1.040
# 372  1333  0.801  1.317

# %%
df = df[df["Visit"] < 3]

# %% [markdown]
# ### Replace Group values
#
# Example of how **Converted** Group should be handeled:
#
# - before:
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 1
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 2
#
# - after:
#
#     - Subject ID = OAS2_0020,Group = Nondemented, Visit = 1
#
#     - Subject ID = OAS2_0020,Group = Demented, Visit = 2

# %%
df.iloc[20:30]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 62  OAS2_0034  Nondemented      1         0    0   79    16    1  29.0  0.0
# 63  OAS2_0034  Nondemented      2       489    0   80    16    1  30.0  0.0
# 68  OAS2_0036  Nondemented      1         0    0   69    13    4  30.0  0.0
# 69  OAS2_0036  Nondemented      2       713    0   70    13    4  30.0  0.0
# 72  OAS2_0037     Demented      1         0    1   82    12    4  27.0  0.5
# 73  OAS2_0037     Demented      2      1123    1   85    12    4  29.0  0.5
# 78  OAS2_0040     Demented      1         0    1   84     6    4  25.0  0.5
# 79  OAS2_0040     Demented      2       567    1   86     6    4  27.0  0.5
# 81  OAS2_0041    Converted      1         0    0   71    16    1  27.0  0.0
# 82  OAS2_0041    Converted      2       756    0   73    16    1  28.0  0.0
#
#     eTIV   nWBV    ASF
# 62  1466  0.703  1.197
# 63  1450  0.698  1.210
# 68  1359  0.789  1.291
# 69  1361  0.783  1.290
# 72  1477  0.729  1.188
# 73  1487  0.717  1.180
# 78  1310  0.727  1.339
# 79  1320  0.724  1.329
# 81  1289  0.771  1.362
# 82  1295  0.768  1.356

# %%
max_visit = df[df["Group"] == "Converted"].groupby(["Subject ID"]).max().reset_index()[["Subject ID","Visit"]]
for i in range(max_visit.shape[0]):
    target_index =  df[(df["Subject ID"] == max_visit.loc[i,"Subject ID"]) & (df["Visit"] != max_visit.loc[i,"Visit"]) ].index
    df.loc[target_index,"Group"] = "Nondemented"

# %%
visit_3

# %%
df.iloc[20:30]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 62  OAS2_0034  Nondemented      1         0    0   79    16    1  29.0  0.0
# 63  OAS2_0034  Nondemented      2       489    0   80    16    1  30.0  0.0
# 68  OAS2_0036  Nondemented      1         0    0   69    13    4  30.0  0.0
# 69  OAS2_0036  Nondemented      2       713    0   70    13    4  30.0  0.0
# 72  OAS2_0037     Demented      1         0    1   82    12    4  27.0  0.5
# 73  OAS2_0037     Demented      2      1123    1   85    12    4  29.0  0.5
# 78  OAS2_0040     Demented      1         0    1   84     6    4  25.0  0.5
# 79  OAS2_0040     Demented      2       567    1   86     6    4  27.0  0.5
# 81  OAS2_0041  Nondemented      1         0    0   71    16    1  27.0  0.0
# 82  OAS2_0041    Converted      2       756    0   73    16    1  28.0  0.0
#
#     eTIV   nWBV    ASF
# 62  1466  0.703  1.197
# 63  1450  0.698  1.210
# 68  1359  0.789  1.291
# 69  1361  0.783  1.290
# 72  1477  0.729  1.188
# 73  1487  0.717  1.180
# 78  1310  0.727  1.339
# 79  1320  0.724  1.329
# 81  1289  0.771  1.362
# 82  1295  0.768  1.356

# %%
df["Group"] = np.where(df["Group"] == "Nondemented", 0, 1)

# %%
df.iloc[20:30]
# Out:
#    Subject ID  Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV  \
# 62  OAS2_0034      0      1         0    0   79    16    1  29.0  0.0  1466
# 63  OAS2_0034      0      2       489    0   80    16    1  30.0  0.0  1450
# 68  OAS2_0036      0      1         0    0   69    13    4  30.0  0.0  1359
# 69  OAS2_0036      0      2       713    0   70    13    4  30.0  0.0  1361
# 72  OAS2_0037      1      1         0    1   82    12    4  27.0  0.5  1477
# 73  OAS2_0037      1      2      1123    1   85    12    4  29.0  0.5  1487
# 78  OAS2_0040      1      1         0    1   84     6    4  25.0  0.5  1310
# 79  OAS2_0040      1      2       567    1   86     6    4  27.0  0.5  1320
# 81  OAS2_0041      0      1         0    0   71    16    1  27.0  0.0  1289
# 82  OAS2_0041      1      2       756    0   73    16    1  28.0  0.0  1295
#
#      nWBV    ASF
# 62  0.703  1.197
# 63  0.698  1.210
# 68  0.789  1.291
# 69  0.783  1.290
# 72  0.729  1.188
# 73  0.717  1.180
# 78  0.727  1.339
# 79  0.724  1.329
# 81  0.771  1.362
# 82  0.768  1.356

# %% [markdown]
# ## Processing

# %% [markdown]
# ### A list to remember and compare details

# %%
model_details = []

# %% [markdown]
# ### Split Data

# %%
# GroupShuffleSplit should be used because it is important to model to learn each patient fully (all visit for each patient).
splitter = GroupShuffleSplit(test_size=.20, n_splits=1, random_state = RANDOM_STATE)

# %%
split = splitter.split(df, groups=df['Subject ID'])
train_indexes, test_indexes = next(split)

train = df.iloc[train_indexes]
test = df.iloc[test_indexes]

# %%
X_train = train.drop(["Group"], axis = 1).reset_index(drop = True) # "Subject ID",
y_train = train[["Group"]].reset_index(drop = True).reset_index(drop = True)

# %%
X_train
# Out:
#    Subject ID  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV  \
# 0   OAS2_0005      1         0    1   80    12    4  28.0  0.0  1689  0.712
# 1   OAS2_0005      2      1010    1   83    12    4  29.0  0.5  1701  0.711
# 2   OAS2_0007      1         0    1   71    16    2  28.0  0.5  1357  0.748
# 3   OAS2_0007      2       518    1   73    16    2  27.0  1.0  1365  0.727
# 4   OAS2_0012      1         0    0   78    16    2  29.0  0.0  1333  0.748
# ..        ...    ...       ...  ...  ...   ...  ...   ...  ...   ...    ...
# 83  OAS2_0183      2       182    0   66    13    2  30.0  0.0  1506  0.740
# 84  OAS2_0185      1         0    1   80    16    1  28.0  0.5  1704  0.711
# 85  OAS2_0185      2       842    1   82    16    1  28.0  0.5  1693  0.694
# 86  OAS2_0186      1         0    0   61    13    2  30.0  0.0  1319  0.801
# 87  OAS2_0186      2       763    0   63    13    2  30.0  0.0  1327  0.796
#
#       ASF
# 0   1.039
# 1   1.032
# 2   1.293
# 3   1.286
# 4   1.316
# ..    ...
# 83  1.165
# 84  1.030
# 85  1.037
# 86  1.331
# 87  1.323
#
# [88 rows x 12 columns]

# %%
X_test = test.drop(["Group"], axis = 1).reset_index(drop = True) #‌ "Subject ID",
y_test = test[["Group"]].reset_index(drop = True)

# %% [markdown]
# ### Normalization

# %%
delay_scaler = MinMaxScaler()
age_scaler = MinMaxScaler()
educ_scaler = MinMaxScaler()
mmse_scaler = MinMaxScaler()
etiv_scaler = MinMaxScaler()

delay_scaler.fit(X_train["MR Delay"].to_numpy().reshape(-1,1))
age_scaler.fit(X_train["Age"].to_numpy().reshape(-1,1))
educ_scaler.fit(X_train["EDUC"].to_numpy().reshape(-1,1))
mmse_scaler.fit(X_train["MMSE"].to_numpy().reshape(-1,1))
etiv_scaler.fit(X_train["eTIV"].to_numpy().reshape(-1,1))

X_train["MR Delay"] = delay_scaler.transform(X_train["MR Delay"].to_numpy().reshape(-1,1))
X_train["Age"] = age_scaler.transform(X_train["Age"].to_numpy().reshape(-1,1))
X_train["EDUC"] = educ_scaler.transform(X_train["EDUC"].to_numpy().reshape(-1,1))
X_train["MMSE"] = mmse_scaler.transform(X_train["MMSE"].to_numpy().reshape(-1,1))
X_train["eTIV"] = etiv_scaler.transform(X_train["eTIV"].to_numpy().reshape(-1,1))

X_test["MR Delay"] = delay_scaler.transform(X_test["MR Delay"].to_numpy().reshape(-1,1))
X_test["Age"] = age_scaler.transform(X_test["Age"].to_numpy().reshape(-1,1))
X_test["EDUC"] = educ_scaler.transform(X_test["EDUC"].to_numpy().reshape(-1,1))
X_test["MMSE"] = mmse_scaler.transform(X_test["MMSE"].to_numpy().reshape(-1,1))
X_test["eTIV"] = etiv_scaler.transform(X_test["eTIV"].to_numpy().reshape(-1,1))

# %% [markdown]
# ## Train Test Final

# %%
y_train_final = []
for id in X_train["Subject ID"].unique():
    res = visit_3[visit_3["Subject ID"] == id]["Group"].values[0]
    if res == "Nondemented":
        y_train_final.append(0)
    else:
        y_train_final.append(1)

# %%
y_train_final_df = pd.DataFrame({
    "Group": y_train_final
})

# %%
y_test_final = []
for id in X_test["Subject ID"].unique():
    res = visit_3[visit_3["Subject ID"] == id]["Group"].values[0]
    if res == "Nondemented":
        y_test_final.append(0)
    else:
        y_test_final.append(1)

# %%
y_test_final_df = pd.DataFrame({
    "Group": y_test_final
})

# %%
X_test_final = X_test.drop(["Subject ID"], axis = 1)
X_train_final = X_train.drop(["Subject ID"], axis = 1)

# %%
X_train_super_final = np.reshape(X_train_final.to_numpy(),(X_train_final.shape[0]//2,11,2))
X_test_super_final = np.reshape(X_test_final.to_numpy(),(X_test_final.shape[0]//2,11,2))

# %%
X_train_super_final.shape
# Out:
# (44, 11, 2)

# %% [markdown]
# ### RNN LSTM

# %%
def build_lstm_rnn():
    lstm_rnn = tf.keras.Sequential()
    lstm_rnn.add(tf.keras.layers.LSTM(100, return_sequences = True,input_shape = (X_train_super_final.shape[1],X_train_super_final.shape[2]) ) )
    lstm_rnn.add(tf.keras.layers.LSTM(50,return_sequences = False))
    lstm_rnn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    lstm_rnn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return lstm_rnn

# %%
lstm_rnn = build_lstm_rnn()
lstm_rnn.fit(X_train_super_final, y_train_final_df, epochs = 100)
not_final_lstm_rnn_prediction = lstm_rnn.predict(X_test_super_final)
lstm_rnn_prediction = np.where(not_final_lstm_rnn_prediction > 0.5, 1, 0)
print(classification_report(y_test_final_df,lstm_rnn_prediction, target_names= ["Non-Demanted", "Demanted"]))
lstm_rnn_conf = confusion_matrix(y_test_final_df,lstm_rnn_prediction)
model_details.append(["LSTM RNN", round(f1_score(y_test_final_df,lstm_rnn_prediction, average = "weighted") * 100,4),lstm_rnn_conf[1,0]])
lstm_rnn_plot_conf = ConfusionMatrixDisplay(lstm_rnn_conf)
lstm_rnn_plot_conf.plot()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 5s 26ms/step - loss: 0.6902 - accuracy: 0.6364
# Epoch 2/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6680 - accuracy: 0.6364
# Epoch 3/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6620 - accuracy: 0.6364
# Epoch 4/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6610 - accuracy: 0.6364
# Epoch 5/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6685 - accuracy: 0.6364
# Epoch 6/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6742 - accuracy: 0.6364
# Epoch 7/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6740 - accuracy: 0.6364
# Epoch 8/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6740 - accuracy: 0.6364
# Epoch 9/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6665 - accuracy: 0.6364
# Epoch 10/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6644 - accuracy: 0.6364
# Epoch 11/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.6620 - accuracy: 0.6364
# Epoch 12/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6602 - accuracy: 0.6364
# Epoch 13/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6584 - accuracy: 0.6364
# Epoch 14/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6590 - accuracy: 0.6364
# Epoch 15/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6583 - accuracy: 0.6364
# Epoch 16/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6580 - accuracy: 0.6364
# Epoch 17/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6572 - accuracy: 0.6364
# Epoch 18/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6569 - accuracy: 0.6364
# Epoch 19/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6563 - accuracy: 0.6364
# Epoch 20/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6554 - accuracy: 0.6364
# Epoch 21/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6551 - accuracy: 0.6364
# Epoch 22/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6536 - accuracy: 0.6364
# Epoch 23/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6529 - accuracy: 0.6364
# Epoch 24/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6514 - accuracy: 0.6364
# Epoch 25/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6504 - accuracy: 0.6364
# Epoch 26/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6489 - accuracy: 0.6364
# Epoch 27/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6484 - accuracy: 0.6364
# Epoch 28/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.6476 - accuracy: 0.6364
# Epoch 29/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6447 - accuracy: 0.6364
# Epoch 30/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6428 - accuracy: 0.6364
# Epoch 31/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6398 - accuracy: 0.6364
# Epoch 32/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.6390 - accuracy: 0.6591
# Epoch 33/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6401 - accuracy: 0.7045
# Epoch 34/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6338 - accuracy: 0.7045
# Epoch 35/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6331 - accuracy: 0.6591
# Epoch 36/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6277 - accuracy: 0.6364
# Epoch 37/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6225 - accuracy: 0.6364
# Epoch 38/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6213 - accuracy: 0.6364
# Epoch 39/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6187 - accuracy: 0.6591
# Epoch 40/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6018 - accuracy: 0.7045
# Epoch 41/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5927 - accuracy: 0.7500
# Epoch 42/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5831 - accuracy: 0.7500
# Epoch 43/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5846 - accuracy: 0.6591
# Epoch 44/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.5459 - accuracy: 0.7727
# Epoch 45/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5511 - accuracy: 0.7500
# Epoch 46/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.5261 - accuracy: 0.7500
# Epoch 47/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.5185 - accuracy: 0.7500
# Epoch 48/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4967 - accuracy: 0.7727
# Epoch 49/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5199 - accuracy: 0.7727
# Epoch 50/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4648 - accuracy: 0.7955
# Epoch 51/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4615 - accuracy: 0.7727
# Epoch 52/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4557 - accuracy: 0.8182
# Epoch 53/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4385 - accuracy: 0.8182
# Epoch 54/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4964 - accuracy: 0.7500
# Epoch 55/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4365 - accuracy: 0.8182
# Epoch 56/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4556 - accuracy: 0.8182
# Epoch 57/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.4233 - accuracy: 0.7500
# Epoch 58/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4600 - accuracy: 0.7955
# Epoch 59/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4063 - accuracy: 0.8636
# Epoch 60/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4060 - accuracy: 0.8409
# Epoch 61/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3904 - accuracy: 0.7955
# Epoch 62/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4245 - accuracy: 0.8409
# Epoch 63/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4022 - accuracy: 0.7727
# Epoch 64/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3852 - accuracy: 0.8182
# Epoch 65/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3716 - accuracy: 0.8864
# Epoch 66/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3687 - accuracy: 0.8636
# Epoch 67/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3659 - accuracy: 0.8636
# Epoch 68/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3562 - accuracy: 0.8864
# Epoch 69/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3624 - accuracy: 0.8636
# Epoch 70/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3443 - accuracy: 0.8636
# Epoch 71/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3473 - accuracy: 0.8636
# Epoch 72/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3515 - accuracy: 0.8636
# Epoch 73/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3166 - accuracy: 0.8864
# Epoch 74/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3188 - accuracy: 0.9091
# Epoch 75/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3068 - accuracy: 0.9091
# Epoch 76/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3450 - accuracy: 0.8636
# Epoch 77/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3733 - accuracy: 0.8409
# Epoch 78/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.4595 - accuracy: 0.7727
# Epoch 79/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2937 - accuracy: 0.8864
# Epoch 80/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4643 - accuracy: 0.7955
# Epoch 81/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2939 - accuracy: 0.9091
# Epoch 82/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3387 - accuracy: 0.8409
# Epoch 83/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3226 - accuracy: 0.8864
# Epoch 84/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2935 - accuracy: 0.8864
# Epoch 85/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2868 - accuracy: 0.8636
# Epoch 86/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2956 - accuracy: 0.8864
# Epoch 87/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3073 - accuracy: 0.8864
# Epoch 88/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3030 - accuracy: 0.8864
# Epoch 89/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2912 - accuracy: 0.8636
# Epoch 90/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2781 - accuracy: 0.9091
# Epoch 91/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2804 - accuracy: 0.9091
# Epoch 92/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.2783 - accuracy: 0.9091
# Epoch 93/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2901 - accuracy: 0.8864
# Epoch 94/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2783 - accuracy: 0.9091
# Epoch 95/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2748 - accuracy: 0.8864
# Epoch 96/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2611 - accuracy: 0.8636
# Epoch 97/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2576 - accuracy: 0.8864
# Epoch 98/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2563 - accuracy: 0.9091
# Epoch 99/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2697 - accuracy: 0.9091
# Epoch 100/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2612 - accuracy: 0.8636
# 1/1 [==============================] - 1s 792ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       0.80      0.67      0.73         6
#     Demanted       0.71      0.83      0.77         6
#
#     accuracy                           0.75        12
#    macro avg       0.76      0.75      0.75        12
# weighted avg       0.76      0.75      0.75        12

# %% [markdown]
# ### RNN GRU

# %%
def build_gru_rnn():
    gru_rnn = tf.keras.Sequential()
    gru_rnn.add(tf.keras.layers.GRU(100, return_sequences = True,input_shape = (X_train.shape[1],1) ) )
    gru_rnn.add(tf.keras.layers.GRU(50,return_sequences = False))
    gru_rnn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    gru_rnn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return gru_rnn

# %%
gru_rnn = build_gru_rnn()
gru_rnn.fit(X_train, y_train, epochs = 100)
not_final_gru_rnn_prediction = gru_rnn.predict(X_test)
gru_rnn_prediction = np.where(not_final_gru_rnn_prediction > 0.5, 1, 0)
print(classification_report(y_test,gru_rnn_prediction, target_names= ["Non-Demanted", "Demanted"]))
gru_rnn_conf = confusion_matrix(y_test,gru_rnn_prediction)
model_details.append(["GRU RNN", round(f1_score(y_test,gru_rnn_prediction, average = "weighted") * 100,4),gru_rnn_conf[1,0]])
gru_rnn_plot_conf = ConfusionMatrixDisplay(gru_rnn_conf)
gru_rnn_plot_conf.plot()
# Out:
# Epoch 1/100
# 8/8 [==============================] - 5s 18ms/step - loss: 0.6938 - accuracy: 0.5417
# Epoch 2/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6904 - accuracy: 0.5208
# Epoch 3/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6872 - accuracy: 0.5833
# Epoch 4/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6851 - accuracy: 0.5708
# Epoch 5/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6753 - accuracy: 0.6667
# Epoch 6/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6707 - accuracy: 0.6667
# Epoch 7/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6592 - accuracy: 0.6792
# Epoch 8/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6487 - accuracy: 0.6667
# Epoch 9/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6355 - accuracy: 0.6625
# Epoch 10/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6260 - accuracy: 0.6583
# Epoch 11/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6154 - accuracy: 0.6583
# Epoch 12/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6058 - accuracy: 0.6667
# Epoch 13/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5565 - accuracy: 0.7583
# Epoch 14/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4964 - accuracy: 0.7917
# Epoch 15/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4381 - accuracy: 0.8333
# Epoch 16/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4047 - accuracy: 0.8000
# Epoch 17/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3295 - accuracy: 0.8833
# Epoch 18/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3031 - accuracy: 0.8833
# Epoch 19/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2742 - accuracy: 0.9125
# Epoch 20/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2314 - accuracy: 0.9458
# Epoch 21/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2110 - accuracy: 0.9292
# Epoch 22/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2104 - accuracy: 0.9458
# Epoch 23/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1944 - accuracy: 0.9542
# Epoch 24/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1916 - accuracy: 0.9583
# Epoch 25/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1879 - accuracy: 0.9542
# Epoch 26/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1777 - accuracy: 0.9667
# Epoch 27/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1740 - accuracy: 0.9667
# Epoch 28/100
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1698 - accuracy: 0.9667
# Epoch 29/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1718 - accuracy: 0.9667
# Epoch 30/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1640 - accuracy: 0.9667
# Epoch 31/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1637 - accuracy: 0.9667
# Epoch 32/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1530 - accuracy: 0.9667
# Epoch 33/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1610 - accuracy: 0.9667
# Epoch 34/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1506 - accuracy: 0.9667
# Epoch 35/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1566 - accuracy: 0.9667
# Epoch 36/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1460 - accuracy: 0.9667
# Epoch 37/100
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1415 - accuracy: 0.9667
# Epoch 38/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1464 - accuracy: 0.9667
# Epoch 39/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1461 - accuracy: 0.9667
# Epoch 40/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1563 - accuracy: 0.9542
# Epoch 41/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1657 - accuracy: 0.9583
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1567 - accuracy: 0.9583
# Epoch 43/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1416 - accuracy: 0.9667
# Epoch 44/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1286 - accuracy: 0.9667
# Epoch 45/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1447 - accuracy: 0.9583
# Epoch 46/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1336 - accuracy: 0.9625
# Epoch 47/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1325 - accuracy: 0.9667
# Epoch 48/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1237 - accuracy: 0.9667
# Epoch 49/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1212 - accuracy: 0.9667
# Epoch 50/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1196 - accuracy: 0.9583
# Epoch 51/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1222 - accuracy: 0.9667
# Epoch 52/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1125 - accuracy: 0.9667
# Epoch 53/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1128 - accuracy: 0.9667
# Epoch 54/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1090 - accuracy: 0.9667
# Epoch 55/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1064 - accuracy: 0.9708
# Epoch 56/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1178 - accuracy: 0.9583
# Epoch 57/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1390 - accuracy: 0.9667
# Epoch 58/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1316 - accuracy: 0.9708
# Epoch 59/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1063 - accuracy: 0.9667
# Epoch 60/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1069 - accuracy: 0.9792
# Epoch 61/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1291 - accuracy: 0.9667
# Epoch 62/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1068 - accuracy: 0.9708
# Epoch 63/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1071 - accuracy: 0.9583
# Epoch 64/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1109 - accuracy: 0.9625
# Epoch 65/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1078 - accuracy: 0.9667
# Epoch 66/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1147 - accuracy: 0.9708
# Epoch 67/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0936 - accuracy: 0.9750
# Epoch 68/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0939 - accuracy: 0.9750
# Epoch 69/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1003 - accuracy: 0.9792
# Epoch 70/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0978 - accuracy: 0.9708
# Epoch 71/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0995 - accuracy: 0.9708
# Epoch 72/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1041 - accuracy: 0.9583
# Epoch 73/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1230 - accuracy: 0.9750
# Epoch 74/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1096 - accuracy: 0.9708
# Epoch 75/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1052 - accuracy: 0.9708
# Epoch 76/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0993 - accuracy: 0.9625
# Epoch 77/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0929 - accuracy: 0.9750
# Epoch 78/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0877 - accuracy: 0.9750
# Epoch 79/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0936 - accuracy: 0.9708
# Epoch 80/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0976 - accuracy: 0.9750
# Epoch 81/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0928 - accuracy: 0.9708
# Epoch 82/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0893 - accuracy: 0.9833
# Epoch 83/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1084 - accuracy: 0.9583
# Epoch 84/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1019 - accuracy: 0.9667
# Epoch 85/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0862 - accuracy: 0.9833
# Epoch 86/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0865 - accuracy: 0.9750
# Epoch 87/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0862 - accuracy: 0.9708
# Epoch 88/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0858 - accuracy: 0.9792
# Epoch 89/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0872 - accuracy: 0.9708
# Epoch 90/100
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0870 - accuracy: 0.9833
# Epoch 91/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0975 - accuracy: 0.9583
# Epoch 92/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1074 - accuracy: 0.9667
# Epoch 93/100
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0965 - accuracy: 0.9708
# Epoch 94/100
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1194 - accuracy: 0.9542
# Epoch 95/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0792 - accuracy: 0.9750
# Epoch 96/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0902 - accuracy: 0.9750
# Epoch 97/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0802 - accuracy: 0.9708
# Epoch 98/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0813 - accuracy: 0.9792
# Epoch 99/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0775 - accuracy: 0.9750
# Epoch 100/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0757 - accuracy: 0.9750
# 2/2 [==============================] - 1s 6ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       1.00      1.00      1.00        30
#     Demanted       1.00      1.00      1.00        30
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60

# %% [markdown]
# ## Result

# %%
models = pd.DataFrame(model_details, columns = ["model","score","false_negatives"])
models = models.sort_values(["false_negatives"]).reset_index(drop = True)
models
# Out:
#                     model  score  false_negatives
# 0      LogisticRegression  100.0                0
# 1  RandomForestClassifier  100.0                0
# 2               LinearSVC  100.0                0
# 3                     SNN  100.0                0
# 4                LSTM RNN  100.0                0
# 5                 GRU RNN  100.0                0

# %%
models.to_csv(f"v4_details_random_state_{RANDOM_STATE}.csv", index = False)

# %%
# Author: amyrmahdy
# Date: 1 Jan 2022
