# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.svm import LinearSVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupShuffleSplit
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.metrics import f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Reading

# %%
df = pd.read_csv("oasis_longitudinal.csv")

# %% [markdown]
# ### Set random state

# %%
RANDOM_STATE = 13

# %% [markdown]
# ## EDA

# %%
# MR Delay
# after how many days visit based on first visit

# EDUC
# How many years educate

# SES
# Socioeconomic Status
# 5 means LOW and 1 means HIGH?

# MMSE
# Mini‐Mental State Examination

# CDR
# Clinical Dementia Rating

# eTIV
# Estimated total intracranial volume

# nWBV
# Normalize Whole Brain Volume

# ASF
# Atlas Scaling Factor

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df.tail()
# Out:
#     Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 368    16  1.0  28.0  0.5  1693  0.694  1.037
# 369    16  1.0  26.0  0.5  1688  0.675  1.040
# 370    13  2.0  30.0  0.0  1319  0.801  1.331
# 371    13  2.0  30.0  0.0  1327  0.796  1.323
# 372    13  2.0  30.0  0.0  1333  0.801  1.317

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subject ID  373 non-null    object
#  1   MRI ID      373 non-null    object
#  2   Group       373 non-null    object
#  3   Visit       373 non-null    int64
#  4   MR Delay    373 non-null    int64
#  5   M/F         373 non-null    object
#  6   Hand        373 non-null    object
#  7   Age         373 non-null    int64
#  8   EDUC        373 non-null    int64
#  9   SES         354 non-null    float64
#  10  MMSE        371 non-null    float64
#  11  CDR         373 non-null    float64
#  12  eTIV        373 non-null    int64
#  13  nWBV        373 non-null    float64
#  14  ASF         373 non-null    float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 43.8+ KB

# %%
df.describe()
# Out:
#             Visit     MR Delay         Age        EDUC         SES  \
# count  373.000000   373.000000  373.000000  373.000000  354.000000
# mean     1.882038   595.104558   77.013405   14.597855    2.460452
# std      0.922843   635.485118    7.640957    2.876339    1.134005
# min      1.000000     0.000000   60.000000    6.000000    1.000000
# 25%      1.000000     0.000000   71.000000   12.000000    2.000000
# 50%      2.000000   552.000000   77.000000   15.000000    2.000000
# 75%      2.000000   873.000000   82.000000   16.000000    3.000000
# max      5.000000  2639.000000   98.000000   23.000000    5.000000
#
#              MMSE         CDR         eTIV        nWBV         ASF
# count  371.000000  373.000000   373.000000  373.000000  373.000000
# mean    27.342318    0.290885  1488.128686    0.729568    1.195461
# std      3.683244    0.374557   176.139286    0.037135    0.138092
# min      4.000000    0.000000  1106.000000    0.644000    0.876000
# 25%     27.000000    0.000000  1357.000000    0.700000    1.099000
# 50%     29.000000    0.000000  1470.000000    0.729000    1.194000
# 75%     30.000000    0.500000  1597.000000    0.756000    1.293000
# max     30.000000    2.000000  2004.000000    0.837000    1.587000

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Handeling SES nan values

# %%
df.SES.hist(figsize = (10,5))
# Out:
# <AxesSubplot: >

# %%
df.SES.mean()
# Out:
# 2.4604519774011298

# %%
df.SES.unique()
# Out:
# array([ 2., nan,  3.,  4.,  1.,  5.])

# %%
df.groupby(["SES"]).mean()
# Out:
# /tmp/ipykernel_8698/2585948393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["SES"]).mean()
#         Visit    MR Delay        Age       EDUC       MMSE       CDR  \
# SES
# 1.0  2.011364  672.181818  77.829545  17.340909  27.602273  0.301136
# 2.0  1.815534  562.961165  76.679612  15.446602  28.067961  0.179612
# 3.0  1.865854  555.634146  77.243902  13.987805  27.573171  0.280488
# 4.0  1.864865  632.851351  76.243243  11.959459  26.378378  0.337838
# 5.0  1.714286  478.428571  78.142857   8.000000  24.285714  0.428571
#
#             eTIV      nWBV       ASF
# SES
# 1.0  1571.204545  0.716614  1.131739
# 2.0  1489.339806  0.735223  1.195087
# 3.0  1442.573171  0.741890  1.229829
# 4.0  1460.202703  0.725595  1.214378
# 5.0  1349.000000  0.722571  1.314429

# %%
# fill nan values function for SES
def fill_ses(x):
    ses = 0
    if x > 17:
        ses = 1.0
    elif (x < 17) and (x > 15):
        ses = 2.0
    elif (x < 15) and (x > 13):
        ses = 3.0
    elif (x < 13) and (x > 11):
        ses = 4.0
    else:
        ses = 5.0
    return ses

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df["SES"] = df.apply(lambda x : fill_ses(x.EDUC) if pd.isna(x.SES)   else x.SES, axis = 1)

# %%
# convert float to int to use less memory
df["SES"] = df.SES.astype(int)

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    2  27.0  0.0  1987  0.696  0.883
# 1    2  30.0  0.0  2004  0.681  0.876
# 2    4  23.0  0.5  1678  0.736  1.046
# 3    4  28.0  0.5  1738  0.713  1.010
# 4    4  22.0  0.5  1698  0.701  1.034

# %% [markdown]
# ### Handeling MMSE nan values

# %%
df.MMSE.hist()
# Out:
# <AxesSubplot: >

# %%
df.groupby(["MMSE"]).mean()
# Out:
# /tmp/ipykernel_8698/685721936.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["MMSE"]).mean()
#          Visit     MR Delay        Age       EDUC       SES       CDR  \
# MMSE
# 4.0   5.000000  1233.000000  69.000000  16.000000  1.000000  1.000000
# 7.0   4.000000   970.000000  68.000000  16.000000  1.000000  1.000000
# 15.0  2.000000   473.500000  73.500000  14.000000  3.500000  1.500000
# 16.0  2.333333   841.000000  73.666667  13.333333  3.666667  1.000000
# 17.0  1.800000   524.000000  70.000000  12.800000  3.200000  0.800000
# 18.0  2.500000  1023.000000  78.500000  10.000000  3.500000  0.750000
# 19.0  1.666667   215.666667  69.000000  14.666667  1.333333  1.000000
# 20.0  1.571429   372.857143  78.428571  13.285714  3.000000  0.714286
# 21.0  1.545455   315.636364  78.181818  14.181818  3.000000  0.909091
# 22.0  2.000000   646.285714  75.571429  13.142857  3.285714  0.714286
# 23.0  1.363636   247.090909  78.727273  11.727273  3.363636  0.636364
# 24.0  1.750000   516.000000  80.000000  14.500000  2.250000  0.500000
# 25.0  1.500000   380.333333  76.666667  14.250000  2.416667  0.625000
# 26.0  1.750000   633.150000  79.300000  14.850000  2.900000  0.500000
# 27.0  1.968750   529.843750  79.093750  13.187500  2.843750  0.453125
# 28.0  1.866667   597.933333  77.222222  14.533333  2.466667  0.222222
# 29.0  1.846154   612.197802  77.593407  15.219780  2.395604  0.109890
# 30.0  1.982456   676.798246  75.947368  15.228070  2.245614  0.078947
#
#              eTIV      nWBV       ASF
# MMSE
# 4.0   1701.000000  0.676000  1.032000
# 7.0   1714.000000  0.682000  1.024000
# 15.0  1366.000000  0.689000  1.285500
# 16.0  1520.000000  0.705667  1.156000
# 17.0  1569.000000  0.701400  1.122600
# 18.0  1471.500000  0.669500  1.193000
# 19.0  1560.333333  0.710000  1.146000
# 20.0  1555.000000  0.700429  1.138000
# 21.0  1439.000000  0.683727  1.232091
# 22.0  1456.857143  0.713286  1.221286
# 23.0  1545.636364  0.714727  1.141273
# 24.0  1355.000000  0.720750  1.299250
# 25.0  1481.916667  0.727167  1.210000
# 26.0  1472.650000  0.718150  1.210000
# 27.0  1449.281250  0.729656  1.224156
# 28.0  1497.088889  0.737422  1.188222
# 29.0  1476.747253  0.734220  1.205967
# 30.0  1507.614035  0.738833  1.179246

# %%
df["MMSE"].mean()
# Out:
# 27.342318059299192

# %%
df["MMSE"].median()
# Out:
# 29.0

# %%
df[df["MMSE"].isna()]
# Out:
#     Subject ID         MRI ID     Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 357  OAS2_0181  OAS2_0181_MR2  Demented      2       539   F    R   75    12
# 358  OAS2_0181  OAS2_0181_MR3  Demented      3      1107   F    R   77    12
#
#      SES  MMSE  CDR  eTIV   nWBV    ASF
# 357    4   NaN  1.0  1169  0.742  1.501
# 358    4   NaN  1.0  1159  0.733  1.515

# %%
df[df["Group"] == "Demented"]["MMSE"].median()
# Out:
# 26.0

# %%
df[df["MMSE"] < 26]["Group"].unique()
# Out:
# array(['Demented', 'Converted'], dtype=object)

# %%
df["MMSE"] = df.MMSE.fillna(df[df["Group"] == "Demented"]["MMSE"].median())

# %% [markdown]
# ### Replace M/F values

# %%
df["M/F"] = np.where(df["M/F"] == "M", 1, 0)

# %% [markdown]
# ### Drop Hand & MRI ID

# %%
df.drop(["Hand", "MRI ID"], axis = 1, inplace = True)

# %% [markdown]
# ### Handeling Visits

# %%
# 11
df.iloc[10:13,:]
# Out:
#    Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 10  OAS2_0007  Demented      1         0    1   71    16    2  28.0  0.5
# 11  OAS2_0007  Demented      3       518    1   73    16    2  27.0  1.0
# 12  OAS2_0007  Demented      4      1281    1   75    16    2  27.0  1.0
#
#     eTIV   nWBV    ASF
# 10  1357  0.748  1.293
# 11  1365  0.727  1.286
# 12  1372  0.710  1.279

# %%
# 11
df.loc[11,'Visit'] = 2
df.loc[12,'Visit'] = 3
df.iloc[10:13,:]
# Out:
#    Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 10  OAS2_0007  Demented      1         0    1   71    16    2  28.0  0.5
# 11  OAS2_0007  Demented      2       518    1   73    16    2  27.0  1.0
# 12  OAS2_0007  Demented      3      1281    1   75    16    2  27.0  1.0
#
#     eTIV   nWBV    ASF
# 10  1357  0.748  1.293
# 11  1365  0.727  1.286
# 12  1372  0.710  1.279

# %%
# 30
df.iloc[29:33,:]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 29  OAS2_0017  Nondemented      1         0    1   80    12    3  29.0  0.0
# 30  OAS2_0017  Nondemented      3       617    1   81    12    3  27.0  0.5
# 31  OAS2_0017  Nondemented      4      1861    1   85    12    3  30.0  0.0
# 32  OAS2_0017  Nondemented      5      2400    1   86    12    3  27.0  0.0
#
#     eTIV   nWBV    ASF
# 29  1783  0.752  0.985
# 30  1814  0.759  0.968
# 31  1820  0.755  0.964
# 32  1813  0.761  0.968

# %%
# 30
df.loc[30,'Visit'] = 2
df.loc[31,'Visit'] = 3
df.loc[32,'Visit'] = 4
df.iloc[29:33,:]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 29  OAS2_0017  Nondemented      1         0    1   80    12    3  29.0  0.0
# 30  OAS2_0017  Nondemented      2       617    1   81    12    3  27.0  0.5
# 31  OAS2_0017  Nondemented      3      1861    1   85    12    3  30.0  0.0
# 32  OAS2_0017  Nondemented      4      2400    1   86    12    3  27.0  0.0
#
#     eTIV   nWBV    ASF
# 29  1783  0.752  0.985
# 30  1814  0.759  0.968
# 31  1820  0.755  0.964
# 32  1813  0.761  0.968

# %%
# 34
df.iloc[33:36,:]
# Out:
#    Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 33  OAS2_0018  Converted      1         0    0   87    14    1  30.0  0.0
# 34  OAS2_0018  Converted      3       489    0   88    14    1  29.0  0.0
# 35  OAS2_0018  Converted      4      1933    0   92    14    1  27.0  0.5
#
#     eTIV   nWBV    ASF
# 33  1406  0.715  1.248
# 34  1398  0.713  1.255
# 35  1423  0.696  1.234

# %%
# 34
df.loc[34,'Visit'] = 2
df.loc[35,'Visit'] = 3
df.iloc[33:36,:]
# Out:
#    Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 33  OAS2_0018  Converted      1         0    0   87    14    1  30.0  0.0
# 34  OAS2_0018  Converted      2       489    0   88    14    1  29.0  0.0
# 35  OAS2_0018  Converted      3      1933    0   92    14    1  27.0  0.5
#
#     eTIV   nWBV    ASF
# 33  1406  0.715  1.248
# 34  1398  0.713  1.255
# 35  1423  0.696  1.234

# %%
# 69
df.iloc[68:71]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 68  OAS2_0036  Nondemented      1         0    0   69    13    4  30.0  0.0
# 69  OAS2_0036  Nondemented      3       713    0   70    13    4  30.0  0.0
# 70  OAS2_0036  Nondemented      4      1770    0   73    13    4  30.0  0.0
#
#     eTIV   nWBV    ASF
# 68  1359  0.789  1.291
# 69  1361  0.783  1.290
# 70  1360  0.773  1.291

# %%
# 69
df.loc[69,'Visit'] = 2
df.loc[70,'Visit'] = 3
df.iloc[68:71]
# Out:
#    Subject ID        Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 68  OAS2_0036  Nondemented      1         0    0   69    13    4  30.0  0.0
# 69  OAS2_0036  Nondemented      2       713    0   70    13    4  30.0  0.0
# 70  OAS2_0036  Nondemented      3      1770    0   73    13    4  30.0  0.0
#
#     eTIV   nWBV    ASF
# 68  1359  0.789  1.291
# 69  1361  0.783  1.290
# 70  1360  0.773  1.291

# %%
# 188
df.iloc[187:189]
# Out:
#     Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 187  OAS2_0089  Demented      1         0    1   70    12    2  29.0  0.5
# 188  OAS2_0089  Demented      3       563    1   72    12    2  27.0  1.0
#
#      eTIV   nWBV    ASF
# 187  1432  0.692  1.225
# 188  1432  0.684  1.226

# %%
# 188
df.loc[188,'Visit'] = 2
df.iloc[187:189]
# Out:
#     Subject ID     Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 187  OAS2_0089  Demented      1         0    1   70    12    2  29.0  0.5
# 188  OAS2_0089  Demented      2       563    1   72    12    2  27.0  1.0
#
#      eTIV   nWBV    ASF
# 187  1432  0.692  1.225
# 188  1432  0.684  1.226

# %%
# 274
df.iloc[273:275]
# Out:
#     Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 273  OAS2_0133  Converted      1         0    0   78    12    3  29.0  0.0
# 274  OAS2_0133  Converted      3      1006    0   81    12    3  28.0  0.5
#
#      eTIV   nWBV    ASF
# 273  1475  0.731  1.190
# 274  1495  0.687  1.174

# %%
# 274
df.loc[274,'Visit'] = 2
df.iloc[273:275]
# Out:
#     Subject ID      Group  Visit  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  \
# 273  OAS2_0133  Converted      1         0    0   78    12    3  29.0  0.0
# 274  OAS2_0133  Converted      2      1006    0   81    12    3  28.0  0.5
#
#      eTIV   nWBV    ASF
# 273  1475  0.731  1.190
# 274  1495  0.687  1.174

# %% [markdown]
# ### Cut only firsts and seconds and third visits

# %%
df_copy = df.copy()

# %%
has_third_subject_id = df[df["Visit"] == 3]["Subject ID"].values

# %%
df = df[df['Subject ID'].isin(has_third_subject_id)]

# %%
df = df[df["Visit"] < 4]

# %%
df.reset_index(drop = True, inplace = True)

# %%
df = pd.get_dummies(df, columns = ["Visit"],prefix = "Visit")

# %% [markdown]
# ### Replace Group values
#
# Example of how **Converted** Group should be handeled:
#
# - before:
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 1
#
#     - Subject ID = OAS2_0020,Group = Converted, Visit = 2
#
# - after:
#
#     - Subject ID = OAS2_0020,Group = Nondemented, Visit = 1
#
#     - Subject ID = OAS2_0020,Group = Demented, Visit = 2

# %%
df.iloc[40:45]
# Out:
#    Subject ID      Group  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV  \
# 40  OAS2_0040   Demented       567    1   86     6    4  27.0  0.5  1320
# 41  OAS2_0040   Demented      1204    1   88     6    4  23.0  0.5  1348
# 42  OAS2_0041  Converted         0    0   71    16    1  27.0  0.0  1289
# 43  OAS2_0041  Converted       756    0   73    16    1  28.0  0.0  1295
# 44  OAS2_0041  Converted      1331    0   75    16    1  28.0  0.5  1314
#
#      nWBV    ASF  Visit_1  Visit_2  Visit_3
# 40  0.724  1.329        0        1        0
# 41  0.713  1.302        0        0        1
# 42  0.771  1.362        1        0        0
# 43  0.768  1.356        0        1        0
# 44  0.760  1.335        0        0        1

# %%
def handle_converted(x):
    gp = x.Group
    v3 = x.Visit_3
    if gp == "Demented":
        return 1
    elif gp == "Nondemented":
        return 0
    else:
        if v3 == 1:
            return 1
        else:
            return 0

# %%
df["Group"] = df.apply(lambda x : handle_converted(x), axis = 1)

# %%
df.head()
# Out:
#   Subject ID  Group  MR Delay  M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV  \
# 0  OAS2_0002      1         0    1   75    12    4  23.0  0.5  1678  0.736
# 1  OAS2_0002      1       560    1   76    12    4  28.0  0.5  1738  0.713
# 2  OAS2_0002      1      1895    1   80    12    4  22.0  0.5  1698  0.701
# 3  OAS2_0005      0         0    1   80    12    4  28.0  0.0  1689  0.712
# 4  OAS2_0005      0      1010    1   83    12    4  29.0  0.5  1701  0.711
#
#      ASF  Visit_1  Visit_2  Visit_3
# 0  1.046        1        0        0
# 1  1.010        0        1        0
# 2  1.034        0        0        1
# 3  1.039        1        0        0
# 4  1.032        0        1        0

# %%
visit_3 = df[df["Visit_3"] == 1][["Subject ID","Group"]]
df = df.drop(visit_3.index, axis = 0).reset_index(drop = True).drop("Visit_3", axis = 1)

# %% [markdown]
# ## Processing

# %% [markdown]
# ### A list to remember and compare details

# %%
model_details = []

# %% [markdown]
# ### Split Data

# %%
# GroupShuffleSplit should be used because it is important to model to learn each patient fully (all visit for each patient).
splitter = GroupShuffleSplit(test_size=.20, n_splits=1, random_state = RANDOM_STATE)

# %%
split = splitter.split(df, groups=df['Subject ID'])
train_indexes, test_indexes = next(split)

X_train = df.iloc[train_indexes]
X_test = df.iloc[test_indexes]

# %% [markdown]
# ### Normalization

# %%
delay_scaler = MinMaxScaler()
age_scaler = MinMaxScaler()
educ_scaler = MinMaxScaler()
mmse_scaler = MinMaxScaler()
etiv_scaler = MinMaxScaler()

delay_scaler.fit(X_train["MR Delay"].to_numpy().reshape(-1,1))
age_scaler.fit(X_train["Age"].to_numpy().reshape(-1,1))
educ_scaler.fit(X_train["EDUC"].to_numpy().reshape(-1,1))
mmse_scaler.fit(X_train["MMSE"].to_numpy().reshape(-1,1))
etiv_scaler.fit(X_train["eTIV"].to_numpy().reshape(-1,1))

X_train["MR Delay"] = delay_scaler.transform(X_train["MR Delay"].to_numpy().reshape(-1,1))
X_train["Age"] = age_scaler.transform(X_train["Age"].to_numpy().reshape(-1,1))
X_train["EDUC"] = educ_scaler.transform(X_train["EDUC"].to_numpy().reshape(-1,1))
X_train["MMSE"] = mmse_scaler.transform(X_train["MMSE"].to_numpy().reshape(-1,1))
X_train["eTIV"] = etiv_scaler.transform(X_train["eTIV"].to_numpy().reshape(-1,1))

X_test["MR Delay"] = delay_scaler.transform(X_test["MR Delay"].to_numpy().reshape(-1,1))
X_test["Age"] = age_scaler.transform(X_test["Age"].to_numpy().reshape(-1,1))
X_test["EDUC"] = educ_scaler.transform(X_test["EDUC"].to_numpy().reshape(-1,1))
X_test["MMSE"] = mmse_scaler.transform(X_test["MMSE"].to_numpy().reshape(-1,1))
X_test["eTIV"] = etiv_scaler.transform(X_test["eTIV"].to_numpy().reshape(-1,1))
# Out:
# /tmp/ipykernel_8698/1268356017.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["MR Delay"] = delay_scaler.transform(X_train["MR Delay"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["Age"] = age_scaler.transform(X_train["Age"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["EDUC"] = educ_scaler.transform(X_train["EDUC"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["MMSE"] = mmse_scaler.transform(X_train["MMSE"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train["eTIV"] = etiv_scaler.transform(X_train["eTIV"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["MR Delay"] = delay_scaler.transform(X_test["MR Delay"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["Age"] = age_scaler.transform(X_test["Age"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["EDUC"] = educ_scaler.transform(X_test["EDUC"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["MMSE"] = mmse_scaler.transform(X_test["MMSE"].to_numpy().reshape(-1,1))
# /tmp/ipykernel_8698/1268356017.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["eTIV"] = etiv_scaler.transform(X_test["eTIV"].to_numpy().reshape(-1,1))

# %% [markdown]
# ## Train Test Final

# %%
y_train_final = []
for id in X_train["Subject ID"].unique():
    res = visit_3[visit_3["Subject ID"] == id]["Group"].values[0]
    y_train_final.append(res)

y_test_final = []
for id in X_test["Subject ID"].unique():
    res = visit_3[visit_3["Subject ID"] == id]["Group"].values[0]
    y_test_final.append(res)

# %%
y_train_super_final = pd.DataFrame({
    "Group": y_train_final
})

y_test_super_final = pd.DataFrame({
    "Group": y_test_final
})

# %%
X_test_final = X_test.drop(["Subject ID"], axis = 1)
X_train_final = X_train.drop(["Subject ID"], axis = 1)

# %%
X_train_final
# Out:
#      Group  MR Delay  M/F       Age      EDUC  SES      MMSE  CDR      eTIV  \
# 2        0  0.000000    1  0.588235  0.352941    4  0.866667  0.0  0.764977
# 3        0  0.649936    1  0.676471  0.352941    4  0.933333  0.5  0.783410
# 4        1  0.000000    1  0.323529  0.588235    2  0.866667  0.5  0.254992
# 5        1  0.333333    1  0.382353  0.588235    2  0.800000  1.0  0.267281
# 6        0  0.000000    0  0.529412  0.588235    2  0.933333  0.0  0.218126
# ..     ...       ...  ...       ...       ...  ...       ...  ...       ...
# 107      0  0.117117    0  0.176471  0.411765    2  1.000000  0.0  0.483871
# 108      1  0.000000    1  0.588235  0.588235    1  0.866667  0.5  0.788018
# 109      1  0.541828    1  0.647059  0.588235    1  0.866667  0.5  0.771121
# 110      0  0.000000    0  0.029412  0.411765    2  1.000000  0.0  0.196621
# 111      0  0.490991    0  0.088235  0.411765    2  1.000000  0.0  0.208909
#
#       nWBV    ASF  Visit_1  Visit_2
# 2    0.712  1.039        1        0
# 3    0.711  1.032        0        1
# 4    0.748  1.293        1        0
# 5    0.727  1.286        0        1
# 6    0.748  1.316        1        0
# ..     ...    ...      ...      ...
# 107  0.740  1.165        0        1
# 108  0.711  1.030        1        0
# 109  0.694  1.037        0        1
# 110  0.801  1.331        1        0
# 111  0.796  1.323        0        1
#
# [88 rows x 13 columns]

# %%
rows_n = 2
X_train_super_final = np.reshape(X_train_final.to_numpy(),(X_train_final.shape[0]//2,X_train_final.shape[1],rows_n))
X_test_super_final = np.reshape(X_test_final.to_numpy(),(X_test_final.shape[0]//2,X_train_final.shape[1],rows_n))

# %%
X_train_super_final.shape
# Out:
# (44, 13, 2)

# %% [markdown]
# ### RNN LSTM

# %%
def build_lstm_rnn():
    lstm_rnn = tf.keras.Sequential()
    lstm_rnn.add(tf.keras.layers.LSTM(100, return_sequences = True,input_shape = (X_train_super_final.shape[1],X_train_super_final.shape[2]) ) )
    lstm_rnn.add(tf.keras.layers.LSTM(50,return_sequences = False))
    lstm_rnn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    lstm_rnn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return lstm_rnn

# %%
lstm_rnn = build_lstm_rnn()
lstm_rnn.fit(X_train_super_final, y_train_super_final, epochs = 100)
not_final_lstm_rnn_prediction = lstm_rnn.predict(X_test_super_final)
lstm_rnn_prediction = np.where(not_final_lstm_rnn_prediction > 0.5, 1, 0)
print(classification_report(y_test_super_final,lstm_rnn_prediction, target_names= ["Non-Demanted", "Demanted"]))
lstm_rnn_conf = confusion_matrix(y_test_super_final,lstm_rnn_prediction)
model_details.append(["LSTM RNN", round(f1_score(y_test_super_final,lstm_rnn_prediction, average = "weighted") * 100,4),lstm_rnn_conf[1,0]])
lstm_rnn_plot_conf = ConfusionMatrixDisplay(lstm_rnn_conf)
lstm_rnn_plot_conf.plot()
# Out:
# 2023-01-09 07:37:12.795036: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-01-09 07:37:12.795065: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-09 07:37:12.795084: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (cando): /proc/driver/nvidia/version does not exist
# 2023-01-09 07:37:12.795271: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 2/2 [==============================] - 4s 20ms/step - loss: 0.6762 - accuracy: 0.6364
# Epoch 2/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6743 - accuracy: 0.6364
# Epoch 3/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6713 - accuracy: 0.6364
# Epoch 4/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6696 - accuracy: 0.6364
# Epoch 5/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6662 - accuracy: 0.6364
# Epoch 6/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6640 - accuracy: 0.6364
# Epoch 7/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6643 - accuracy: 0.6364
# Epoch 8/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6610 - accuracy: 0.6364
# Epoch 9/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6590 - accuracy: 0.6364
# Epoch 10/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6594 - accuracy: 0.6364
# Epoch 11/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6574 - accuracy: 0.6364
# Epoch 12/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6544 - accuracy: 0.6364
# Epoch 13/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6525 - accuracy: 0.6364
# Epoch 14/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6494 - accuracy: 0.6364
# Epoch 15/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6458 - accuracy: 0.6364
# Epoch 16/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6453 - accuracy: 0.6364
# Epoch 17/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6366 - accuracy: 0.6364
# Epoch 18/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6311 - accuracy: 0.6364
# Epoch 19/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6225 - accuracy: 0.7273
# Epoch 20/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6106 - accuracy: 0.7273
# Epoch 21/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5929 - accuracy: 0.6818
# Epoch 22/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5782 - accuracy: 0.7500
# Epoch 23/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5540 - accuracy: 0.7500
# Epoch 24/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5221 - accuracy: 0.7727
# Epoch 25/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4841 - accuracy: 0.8182
# Epoch 26/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4566 - accuracy: 0.8409
# Epoch 27/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4419 - accuracy: 0.7955
# Epoch 28/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4237 - accuracy: 0.8636
# Epoch 29/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.4186 - accuracy: 0.8409
# Epoch 30/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3790 - accuracy: 0.8864
# Epoch 31/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3769 - accuracy: 0.8636
# Epoch 32/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4581 - accuracy: 0.7500
# Epoch 33/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.4130 - accuracy: 0.7500
# Epoch 34/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3933 - accuracy: 0.8409
# Epoch 35/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3608 - accuracy: 0.8636
# Epoch 36/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3890 - accuracy: 0.7727
# Epoch 37/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3838 - accuracy: 0.8182
# Epoch 38/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.4161 - accuracy: 0.8409
# Epoch 39/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3537 - accuracy: 0.8636
# Epoch 40/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4291 - accuracy: 0.7500
# Epoch 41/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3606 - accuracy: 0.8409
# Epoch 42/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3776 - accuracy: 0.8409
# Epoch 43/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4104 - accuracy: 0.8409
# Epoch 44/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3746 - accuracy: 0.8409
# Epoch 45/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3408 - accuracy: 0.8636
# Epoch 46/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3687 - accuracy: 0.8182
# Epoch 47/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3367 - accuracy: 0.8864
# Epoch 48/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3545 - accuracy: 0.8636
# Epoch 49/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3639 - accuracy: 0.8636
# Epoch 50/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3325 - accuracy: 0.8864
# Epoch 51/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.3388 - accuracy: 0.8636
# Epoch 52/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3443 - accuracy: 0.8636
# Epoch 53/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3362 - accuracy: 0.8636
# Epoch 54/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3212 - accuracy: 0.8864
# Epoch 55/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3184 - accuracy: 0.8636
# Epoch 56/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3173 - accuracy: 0.8636
# Epoch 57/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3245 - accuracy: 0.8409
# Epoch 58/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3262 - accuracy: 0.8409
# Epoch 59/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3132 - accuracy: 0.8636
# Epoch 60/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3067 - accuracy: 0.8636
# Epoch 61/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3076 - accuracy: 0.8636
# Epoch 62/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3022 - accuracy: 0.8636
# Epoch 63/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3077 - accuracy: 0.8864
# Epoch 64/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2993 - accuracy: 0.8864
# Epoch 65/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2914 - accuracy: 0.8636
# Epoch 66/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2989 - accuracy: 0.8409
# Epoch 67/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3011 - accuracy: 0.8409
# Epoch 68/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2965 - accuracy: 0.8409
# Epoch 69/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2959 - accuracy: 0.8636
# Epoch 70/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2907 - accuracy: 0.8636
# Epoch 71/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2828 - accuracy: 0.8636
# Epoch 72/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2824 - accuracy: 0.8864
# Epoch 73/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2824 - accuracy: 0.8864
# Epoch 74/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2796 - accuracy: 0.8864
# Epoch 75/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2771 - accuracy: 0.8864
# Epoch 76/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2723 - accuracy: 0.8864
# Epoch 77/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2689 - accuracy: 0.8864
# Epoch 78/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2693 - accuracy: 0.8864
# Epoch 79/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2673 - accuracy: 0.8864
# Epoch 80/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2637 - accuracy: 0.8864
# Epoch 81/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.2599 - accuracy: 0.8864
# Epoch 82/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2566 - accuracy: 0.8864
# Epoch 83/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2571 - accuracy: 0.8864
# Epoch 84/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2559 - accuracy: 0.8864
# Epoch 85/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2510 - accuracy: 0.8864
# Epoch 86/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2482 - accuracy: 0.8864
# Epoch 87/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2488 - accuracy: 0.9091
# Epoch 88/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2499 - accuracy: 0.9091
# Epoch 89/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2495 - accuracy: 0.9091
# Epoch 90/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2433 - accuracy: 0.9091
# Epoch 91/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2416 - accuracy: 0.8864
# Epoch 92/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2510 - accuracy: 0.8636
# Epoch 93/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2449 - accuracy: 0.8864
# Epoch 94/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2385 - accuracy: 0.9091
# Epoch 95/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2419 - accuracy: 0.9091
# Epoch 96/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2463 - accuracy: 0.9091
# Epoch 97/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2268 - accuracy: 0.9091
# Epoch 98/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2811 - accuracy: 0.8864
# Epoch 99/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2798 - accuracy: 0.8864
# Epoch 100/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2278 - accuracy: 0.9091
# 1/1 [==============================] - 1s 788ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       0.75      1.00      0.86         6
#     Demanted       1.00      0.67      0.80         6
#
#     accuracy                           0.83        12
#    macro avg       0.88      0.83      0.83        12
# weighted avg       0.88      0.83      0.83        12

# %% [markdown]
# ### RNN GRU

# %%
def build_gru_rnn():
    gru_rnn = tf.keras.Sequential()
    gru_rnn.add(tf.keras.layers.GRU(100, return_sequences = True,input_shape = (X_train_super_final.shape[1],X_train_super_final.shape[2])) )
    gru_rnn.add(tf.keras.layers.GRU(50,return_sequences = False))
    gru_rnn.add(tf.keras.layers.Dense(1,activation = "sigmoid"))
    gru_rnn.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
    return gru_rnn

# %%
gru_rnn = build_gru_rnn()
gru_rnn.fit(X_train_super_final, y_train_super_final, epochs = 100)
not_final_gru_rnn_prediction = gru_rnn.predict(X_test_super_final)
gru_rnn_prediction = np.where(not_final_gru_rnn_prediction > 0.5, 1, 0)
print(classification_report(y_test_super_final,gru_rnn_prediction, target_names= ["Non-Demanted", "Demanted"]))
gru_rnn_conf = confusion_matrix(y_test_super_final,gru_rnn_prediction)
model_details.append(["GRU RNN", round(f1_score(y_test_super_final,gru_rnn_prediction, average = "weighted") * 100,4),gru_rnn_conf[1,0]])
gru_rnn_plot_conf = ConfusionMatrixDisplay(gru_rnn_conf)
gru_rnn_plot_conf.plot()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 15ms/step - loss: 0.6815 - accuracy: 0.6364
# Epoch 2/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6673 - accuracy: 0.6364
# Epoch 3/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6617 - accuracy: 0.6364
# Epoch 4/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6591 - accuracy: 0.6364
# Epoch 5/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6539 - accuracy: 0.6364
# Epoch 6/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6507 - accuracy: 0.6364
# Epoch 7/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6499 - accuracy: 0.6364
# Epoch 8/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6499 - accuracy: 0.6364
# Epoch 9/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6452 - accuracy: 0.6364
# Epoch 10/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6420 - accuracy: 0.6364
# Epoch 11/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6388 - accuracy: 0.6364
# Epoch 12/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6361 - accuracy: 0.6364
# Epoch 13/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6347 - accuracy: 0.6591
# Epoch 14/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.6330 - accuracy: 0.6818
# Epoch 15/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6287 - accuracy: 0.7045
# Epoch 16/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6230 - accuracy: 0.7045
# Epoch 17/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6175 - accuracy: 0.6818
# Epoch 18/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.6099 - accuracy: 0.6818
# Epoch 19/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6024 - accuracy: 0.6818
# Epoch 20/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5919 - accuracy: 0.7045
# Epoch 21/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5793 - accuracy: 0.7273
# Epoch 22/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5657 - accuracy: 0.7273
# Epoch 23/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5462 - accuracy: 0.7500
# Epoch 24/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5212 - accuracy: 0.7727
# Epoch 25/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4917 - accuracy: 0.8182
# Epoch 26/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4583 - accuracy: 0.8636
# Epoch 27/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4133 - accuracy: 0.8864
# Epoch 28/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3809 - accuracy: 0.8864
# Epoch 29/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3743 - accuracy: 0.8636
# Epoch 30/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3454 - accuracy: 0.8864
# Epoch 31/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3606 - accuracy: 0.8864
# Epoch 32/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3379 - accuracy: 0.8864
# Epoch 33/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3307 - accuracy: 0.8864
# Epoch 34/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3413 - accuracy: 0.9091
# Epoch 35/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3126 - accuracy: 0.8864
# Epoch 36/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3257 - accuracy: 0.8864
# Epoch 37/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3634 - accuracy: 0.7727
# Epoch 38/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3188 - accuracy: 0.8864
# Epoch 39/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3036 - accuracy: 0.8864
# Epoch 40/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3305 - accuracy: 0.8864
# Epoch 41/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3437 - accuracy: 0.8864
# Epoch 42/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.3228 - accuracy: 0.9318
# Epoch 43/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2920 - accuracy: 0.9318
# Epoch 44/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.3050 - accuracy: 0.9318
# Epoch 45/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3103 - accuracy: 0.9318
# Epoch 46/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2867 - accuracy: 0.9091
# Epoch 47/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2912 - accuracy: 0.8864
# Epoch 48/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2960 - accuracy: 0.8864
# Epoch 49/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2947 - accuracy: 0.8864
# Epoch 50/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2892 - accuracy: 0.8864
# Epoch 51/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2830 - accuracy: 0.8864
# Epoch 52/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2762 - accuracy: 0.8864
# Epoch 53/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2725 - accuracy: 0.8864
# Epoch 54/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2661 - accuracy: 0.8864
# Epoch 55/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2651 - accuracy: 0.9318
# Epoch 56/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2604 - accuracy: 0.9318
# Epoch 57/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2592 - accuracy: 0.9091
# Epoch 58/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2532 - accuracy: 0.9318
# Epoch 59/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2538 - accuracy: 0.9318
# Epoch 60/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2467 - accuracy: 0.9318
# Epoch 61/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2521 - accuracy: 0.9318
# Epoch 62/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2373 - accuracy: 0.9318
# Epoch 63/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2428 - accuracy: 0.9318
# Epoch 64/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2335 - accuracy: 0.9318
# Epoch 65/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2432 - accuracy: 0.9318
# Epoch 66/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2338 - accuracy: 0.9318
# Epoch 67/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2246 - accuracy: 0.9318
# Epoch 68/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2191 - accuracy: 0.9318
# Epoch 69/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2252 - accuracy: 0.9545
# Epoch 70/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2172 - accuracy: 0.9545
# Epoch 71/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2133 - accuracy: 0.9545
# Epoch 72/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2090 - accuracy: 0.9318
# Epoch 73/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2050 - accuracy: 0.9318
# Epoch 74/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1954 - accuracy: 0.9545
# Epoch 75/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1947 - accuracy: 0.9545
# Epoch 76/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1923 - accuracy: 0.9545
# Epoch 77/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1963 - accuracy: 0.9545
# Epoch 78/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1808 - accuracy: 0.9545
# Epoch 79/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1886 - accuracy: 0.9545
# Epoch 80/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1750 - accuracy: 0.9545
# Epoch 81/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1924 - accuracy: 0.9318
# Epoch 82/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1919 - accuracy: 0.9318
# Epoch 83/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1734 - accuracy: 0.9545
# Epoch 84/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1690 - accuracy: 0.9318
# Epoch 85/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2448 - accuracy: 0.9091
# Epoch 86/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1542 - accuracy: 0.9545
# Epoch 87/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1620 - accuracy: 0.9545
# Epoch 88/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.1782 - accuracy: 0.9318
# Epoch 89/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1417 - accuracy: 0.9545
# Epoch 90/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1635 - accuracy: 0.9318
# Epoch 91/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1731 - accuracy: 0.9318
# Epoch 92/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1875 - accuracy: 0.9545
# Epoch 93/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1835 - accuracy: 0.9545
# Epoch 94/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1790 - accuracy: 0.9545
# Epoch 95/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1714 - accuracy: 0.9545
# Epoch 96/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1469 - accuracy: 0.9545
# Epoch 97/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1848 - accuracy: 0.9318
# Epoch 98/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1378 - accuracy: 0.9773
# Epoch 99/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1713 - accuracy: 0.9318
# Epoch 100/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1852 - accuracy: 0.9318
# 1/1 [==============================] - 1s 681ms/step
#               precision    recall  f1-score   support
#
# Non-Demanted       0.71      0.83      0.77         6
#     Demanted       0.80      0.67      0.73         6
#
#     accuracy                           0.75        12
#    macro avg       0.76      0.75      0.75        12
# weighted avg       0.76      0.75      0.75        12

# %% [markdown]
# ## Result

# %%
models = pd.DataFrame(model_details, columns = ["model","score","false_negatives"])
models = models.sort_values(["false_negatives"]).reset_index(drop = True)
models
# Out:
#       model    score  false_negatives
# 0  LSTM RNN  82.8571                2
# 1   GRU RNN  74.8252                2

# %%
models.to_csv(f"v6_details_random_state_{RANDOM_STATE}.csv", index = False)

# %%
# Author: amyrmahdy
# Date: 1 Jan 2022
